# %% [markdown]
# # Nicolas' Mid-Bootcamp Project | A Gastro-Scene Showdown!
#
# **WHICH CITY WILL BE CROWNED GOURMET-CAPITAL OF EUROPE?**
#
# We have 10 exciting cities competing for this most glamorous title! As for our contender selection, I oriented myself by the (European) countries (and cities) of residence of my fellow Ironhack students and from there selected one city (except for Germany) that is sure to offer exciting culinary delights:
# - Dusseldorf, Germany - my city of residence with some fantastic dining options, especially Asian food. But how will it stack up against these major contenders? I promise no bias on my part, just stone-cold data wrangling!
# - Amsterdam, Netherlands - some fantastic (international) eateries here, home of the NL Ironhack remote campus. Thankfully the Dutch West India Company imported more than just goods!
# - Barcelona, Spain - Madrid would also be a fantastic choice for restaurants, tough call but Barceló is just a special kind of cool!
# - Berlin, Germany - bringing in a 2nd German contender against this overbearing cosmopolitan competition, chosen because several from my cohort live here, but also as it has what is probably Germany's most experimental restaurant scene.
# - Istambul, Turkey - a major metropol straddling Europe and Asia, a fusion of east and west! We can expect an exciting culinary scene.
# - Lisbon, Portugal - the cultural and political heart of Portugal, would expect nothing short of fantastic here!
# - London, UK - London breaks conventions, not just with the image of British food in general. A real dine-out heavyweight champ!
# - Milan, Italy - no dining competition complete without some Italian flair. Chosen over Rome for it's fashion fame and economical strength - recipe for a stellar restaurant scene. Carpe Diem!
# - Paris, France - what pan-european food competition would be complete without some 'joie de vivre'?
# - Zurich, Switzerland - no fellow students from here, chosen for my love of Switzerland and Zurich. Honestly cannot remember ever having had a disappointing meal anywhere in CH.
#
# **Questions we seek to answer with the research that follows:**
#
# 1. Which competing city will win the title 'Gourmet Capital of Europe'?
# 2. What is the probability of having a positive dining experience by randomly selecting any restaurant in our contestant cities?
# 3. Which restaurants are the best in each city?
# 4. City Restaurant Heatmaps - Where am I most likely to find a good restaurant? Are there any clusters?
# 5. "Ceap&Cheerful-Meter" (TM) - Which restaurants offer a good bang for your buck?
#
# **INTRODUCTORY NOTE ON DATA METHODOLOGY:**
#
# I had attempted to code a webcrawler to parse Google Maps and scrape restaurant information using Python, but ran into several issues that I was unable to resolve by myself. Instead, I used outscraper.com, an online scraping tool to do the job for me.
#
# Doing so unfortunately limited my sample size to 500 restaurants/rows per city as that was the maximum free query size allowed by the tool. A smaller city target like Dusseldorf or Zurich may or may not actually have around that many restaurants, but major cities like Berlin, Paris or London would likely have far more. Additionally, I had little control over the logic applied by the tool (or rather Google Maps) in giving me my 500 'restaurant' search results per city - though I assume Google would use it's considerable AI clout to deliver results of the most searched/selected/popular restaurants in any given location in descending order. Yet, not all values in each dataset may actually be fully-fledged restaurants - some may be cafés, bakeries or delicacy shops (Et al.) that sell meals, and even some (*shudders*) fast-food franchises.
#
# **GitHub Repository:** https://github.com/NicolasVollmer/My_Ironhack_Mid-Bootcamp_Project
#
# **Presentation on Tableau Online:** https://public.tableau.com/app/profile/nicolas.vollmer/viz/NicolasMid-BootcampProjectAGastro-SceneShowdown/Milan?publish=yes

# %% [markdown]
# ## Startup

# %% [markdown]
# ### Libraries & Setup Imports

# %%
# importing necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import glob # for importing all files concatenated together

# %%
# SQL imports
import pymysql
from sqlalchemy import create_engine
import sqlalchemy.types as sql_types
from getpass import getpass

# %%
password = getpass()
# Out:
# ········

# %%
# setting up engine and connection to MySQL - previously created a new SQL database titled mid_btcmp_project
connection_string = 'mysql+pymysql://root:'+password+'@localhost/mid_btcmp_project'
engine = create_engine(connection_string)

# %%
# override limit on max width of df columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Data Imports & First Look

# %%
# df names for copy/paste requirements:
# dus, bcn, ber, lis, lnd, ams, mil, zrh, ist, par

# %% [markdown]
# #### Importing City Dataframes

# %%
# importing all dataframes individually
dus = pd.read_excel('Datasets/Dusseldorf.xlsx')
bcn = pd.read_excel('Datasets/Barcelona.xlsx')
ber = pd.read_excel('Datasets/Berlin.xlsx')
lis = pd.read_excel('Datasets/Lisbon.xlsx')
lnd = pd.read_excel('Datasets/London.xlsx')
ams = pd.read_excel('Datasets/Amsterdam.xlsx')
mil = pd.read_excel('Datasets/Milan.xlsx')
zrh = pd.read_excel('Datasets/Zurich.xlsx')
ist = pd.read_excel('Datasets/Istambul.xlsx')
par = pd.read_excel('Datasets/Paris.xlsx')

# %%
# list with dfs to call on when needed 
df_lst = [dus, bcn, ber, lis, lnd, ams, mil, zrh, ist, par]

# function to call df name when needed
def city_code(df):
    name = [x for x in globals() if globals()[x] is df][0]
    return name

# finally, function to return shape for all city dfs
def all_shapes():
    for df in df_lst:
        print(city_code(df), df.shape)

# %%
# checking all shapes for conformity

all_shapes()
# Out:
# dus (500, 58)
# bcn (500, 59)
# ber (500, 59)
# lis (500, 59)
# lnd (500, 59)
# ams (500, 59)
# mil (500, 59)
# zrh (500, 59)
# ist (500, 59)
# par (500, 59)

# %%
# noticed that dus oddly has one column less compared to the rest... Checking .head() to find it is missing a column 
# labelled 'area_service' which appears to have no value to our following calculations anyways. 
display(dus.head(1))
bcn.head(1)
# Out:
#                                         query                       name  \
# 0  restaurant, 40210, Nordrhein-Westfalen, DE  Restaurant Zum Schiffchen
#
#                                       site        type    subtypes  \
# 0  https://www.brauerei-zum-schiffchen.de/  Restaurant  Restaurant
#
#       category            phone                                full_address  \
# 0  restaurants  +49 211 1701215  Konrad-Adenauer-Platz 14, 40210 Düsseldorf
#
#          borough                    street        city  postal_code  state  \
# 0  Stadtbezirk 1  Konrad-Adenauer-Platz 14  Düsseldorf        40210    NaN
#
#    us_state  country country_code   latitude  longitude      time_zone  \
# 0       NaN  Germany           DE  51.220276   6.792887  Europe/Berlin
#
#    plus_code  rating  reviews  \
# 0        NaN     3.5    251.0
#
#                                         reviews_link  reviews_tags  \
# 0  https://search.google.com/local/reviews?placei...           NaN
#
#                                reviews_per_score  reviews_per_score_1  \
# 0  {"1": 39, "2": 17, "3": 43, "4": 73, "5": 79}                 39.0
#
#    reviews_per_score_2  reviews_per_score_3  reviews_per_score_4  \
# 0                 17.0                 43.0                 73.0
#
#    reviews_per_score_5  photos_count  \
# 0                 79.0         117.0
#
#                                                photo  \
# 0  https://lh5.googleusercontent.com/p/AF1QipMU8-...
#
#                                          street_view located_in  \
# 0  https://lh5.googleusercontent.com/p/AF1QipMU8-...        NaN
#
#                                        working_hours  \
# 0  {"Monday": "8am-11pm", "Tuesday": "8am-11pm", ...
#
#                             working_hours_old_format other_hours  \
# 0  Monday: 8am-11pm | Tuesday: 8am-11pm | Wednesd...         NaN
#
#    popular_times business_status  \
# 0            NaN     OPERATIONAL
#
#                                                about range  posts  \
# 0  {"Service options": {"Takeaway": true, "Dine-i...    €€    NaN
#
#                                                 logo description  verified  \
# 0  https://lh3.googleusercontent.com/-57mb-s1US0w...         NaN      True
#
#                 owner_id                owner_title  \
# 0  117181584539908212891  Restaurant Zum Schiffchen
#
#                                           owner_link reservation_links  \
# 0  https://www.google.com/maps/contrib/1171815845...               NaN
#
#   booking_appointment_link  menu_link order_links  \
# 0                      NaN        NaN         NaN
#
#                                        location_link  \
# 0  https://www.google.com/maps/place/Restaurant+Z...
#
#                       place_id                              google_id  \
# 0  ChIJdfp4DzHKuEcRZfa1cQU-eT8  0x47b8ca310f78fa75:0x3f793e0571b5f665
#
#                    cid    reviews_id located_google_id
# 0  4573755089674958437  4.573755e+18               NaN
#                              query            name                    site  \
# 0  Restaurant, 08001, Cataluna, ES  RAO Restaurant  http://www.raobcn.com/
#
#          type    subtypes     category             phone  \
# 0  Restaurant  Restaurant  restaurants  +34 655 59 70 21
#
#                                full_address  borough                   street  \
# 0  Carrer de les Sitges, 3, 08001 Barcelona      NaN  Carrer de les Sitges, 3
#
#         city  postal_code      state  us_state country country_code  latitude  \
# 0  Barcelona       8001.0  Barcelona       NaN   Spain           ES  41.38429
#
#    longitude      time_zone  plus_code  area_service  rating  reviews  \
# 0   2.169572  Europe/Madrid        NaN         False     4.7   1022.0
#
#                                         reviews_link  reviews_tags  \
# 0  https://search.google.com/local/reviews?placei...           NaN
#
#                                  reviews_per_score  reviews_per_score_1  \
# 0  {"1": 22, "2": 19, "3": 39, "4": 113, "5": 829}                 22.0
#
#    reviews_per_score_2  reviews_per_score_3  reviews_per_score_4  \
# 0                 19.0                 39.0                113.0
#
#    reviews_per_score_5  photos_count  \
# 0                829.0          1467
#
#                                                photo  \
# 0  https://lh5.googleusercontent.com/p/AF1QipN8K6...
#
#                                          street_view  located_in  \
# 0  https://lh5.googleusercontent.com/p/AF1QipN8K6...         NaN
#
#                                        working_hours  \
# 0  {"Monday": "Closed", "Tuesday": "7PM-12AM", "W...
#
#                             working_hours_old_format other_hours  \
# 0  Monday: Closed | Tuesday: 7PM-12AM | Wednesday...         NaN
#
#    popular_times business_status  \
# 0            NaN     OPERATIONAL
#
#                                                about range  posts  \
# 0  {"Service options": {"Dine-in": true, "Deliver...    €€    NaN
#
#                                                 logo  \
# 0  https://lh5.googleusercontent.com/-XoQulx74O2Q...
#
#                                          description  verified  \
# 0  Edgy, brick-walled space with a terrace, servi...      True
#
#                 owner_id     owner_title  \
# 0  108398980134304825937  RAO Restaurant
#
#                                           owner_link  \
# 0  https://www.google.com/maps/contrib/1083989801...
#
#                                    reservation_links  \
# 0  https://raobcn.com/#!/reservations, https://ww...
#
#              booking_appointment_link  menu_link order_links  \
# 0  https://raobcn.com/#!/reservations        NaN         NaN
#
#                                        location_link  \
# 0  https://www.google.com/maps/place/RAO+Restaura...
#
#                       place_id                              google_id  \
# 0  ChIJZQKuEx6jpBIRAttn9_8h0Dk  0x12a4a31e13ae0265:0x39d021fff767db02
#
#                    cid    reviews_id  located_google_id
# 0  4165867038568864514  4.165867e+18                NaN

# %% [markdown]
# #### Importing Concatenated DF
#
# **To save some time in my initial data overview, I chose to extract all excel files at once from my directory concatenated below**
#
# This way I can gain an overview over all my data at once without having to inspect each city df individually

# %%
# below imports all city files concatenated
dataset_folder = glob.glob("Datasets/*.xlsx")
cities = pd.concat(pd.read_excel(excelFile) for excelFile in dataset_folder)
# Out:
# /var/folders/yb/h9hkbtf17cq8_7fj_jjzdpcm0000gn/T/ipykernel_1018/2079079428.py:3: FutureWarning: Behavior when concatenating bool-dtype and numeric-dtype arrays is deprecated; in a future version these will cast to object dtype (instead of coercing bools to numeric values). To retain the old behavior, explicitly cast bool-dtype arrays to numeric dtype.
#   cities = pd.concat(pd.read_excel(excelFile) for excelFile in dataset_folder)

# %%
# double check shape, checks out
cities.shape
# Out:
# (5000, 59)

# %%
# double check what happens with dus rows on that missing column 'area_service' - it is added and filled with NaNs as I expected
cities[cities['city']=='Düsseldorf'].head(3)
# Out:
#                                         query  \
# 0  restaurant, 40210, Nordrhein-Westfalen, DE
# 1  restaurant, 40210, Nordrhein-Westfalen, DE
# 2  restaurant, 40210, Nordrhein-Westfalen, DE
#
#                                                 name  \
# 0                          Restaurant Zum Schiffchen
# 1                                     Zum Kochlöffel
# 2  BLOCK HOUSE Düsseldorf Hauptbahnhof Harkortstraße
#
#                                       site        type  \
# 0  https://www.brauerei-zum-schiffchen.de/  Restaurant
# 1                                      NaN  Restaurant
# 2              https://www.block-house.de/  Restaurant
#
#                          subtypes     category             phone  \
# 0                      Restaurant  restaurants   +49 211 1701215
# 1                      Restaurant  restaurants   +49 211 1609615
# 2  Restaurant, Takeout restaurant  restaurants  +49 211 30137909
#
#                                   full_address        borough  \
# 0   Konrad-Adenauer-Platz 14, 40210 Düsseldorf  Stadtbezirk 1
# 1  Friedrich-Ebert-Straße 41, 40210 Düsseldorf  Stadtbezirk 1
# 2            Harkortstraße 8, 40210 Düsseldorf  Stadtbezirk 1
#
#                       street        city postal_code state  us_state  country  \
# 0   Konrad-Adenauer-Platz 14  Düsseldorf       40210   NaN       NaN  Germany
# 1  Friedrich-Ebert-Straße 41  Düsseldorf       40210   NaN       NaN  Germany
# 2            Harkortstraße 8  Düsseldorf       40210   NaN       NaN  Germany
#
#   country_code   latitude  longitude      time_zone  plus_code area_service  \
# 0           DE  51.220276   6.792887  Europe/Berlin        NaN          NaN
# 1           DE  51.221250   6.789820  Europe/Berlin        NaN          NaN
# 2           DE  51.219459   6.792052  Europe/Berlin        NaN          NaN
#
#    rating  reviews                                       reviews_link  \
# 0     3.5    251.0  https://search.google.com/local/reviews?placei...
# 1     4.5    116.0  https://search.google.com/local/reviews?placei...
# 2     4.5    135.0  https://search.google.com/local/reviews?placei...
#
#    reviews_tags                              reviews_per_score  \
# 0           NaN  {"1": 39, "2": 17, "3": 43, "4": 73, "5": 79}
# 1           NaN     {"1": 0, "2": 2, "3": 9, "4": 29, "5": 76}
# 2           NaN     {"1": 8, "2": 3, "3": 5, "4": 22, "5": 97}
#
#    reviews_per_score_1  reviews_per_score_2  reviews_per_score_3  \
# 0                 39.0                 17.0                 43.0
# 1                  0.0                  2.0                  9.0
# 2                  8.0                  3.0                  5.0
#
#    reviews_per_score_4  reviews_per_score_5  photos_count  \
# 0                 73.0                 79.0         117.0
# 1                 29.0                 76.0          18.0
# 2                 22.0                 97.0         284.0
#
#                                                photo  \
# 0  https://lh5.googleusercontent.com/p/AF1QipMU8-...
# 1  https://lh5.googleusercontent.com/p/AF1QipNyyl...
# 2  https://lh5.googleusercontent.com/p/AF1QipO0So...
#
#                                          street_view located_in  \
# 0  https://lh5.googleusercontent.com/p/AF1QipMU8-...        NaN
# 1  https://lh5.googleusercontent.com/p/AF1QipNyyl...        NaN
# 2  https://lh5.googleusercontent.com/p/AF1QipO0So...        NaN
#
#                                        working_hours  \
# 0  {"Monday": "8am-11pm", "Tuesday": "8am-11pm", ...
# 1  {"Monday": "6am-5pm", "Tuesday": "6am-5pm", "W...
# 2  {"Monday": "12-10pm", "Tuesday": "12-10pm", "W...
#
#                             working_hours_old_format other_hours  \
# 0  Monday: 8am-11pm | Tuesday: 8am-11pm | Wednesd...         NaN
# 1  Monday: 6am-5pm | Tuesday: 6am-5pm | Wednesday...         NaN
# 2  Monday: 12-10pm | Tuesday: 12-10pm | Wednesday...         NaN
#
#    popular_times business_status  \
# 0            NaN     OPERATIONAL
# 1            NaN     OPERATIONAL
# 2            NaN     OPERATIONAL
#
#                                                about range  posts  \
# 0  {"Service options": {"Takeaway": true, "Dine-i...    €€    NaN
# 1  {"Service options": {"Takeaway": true, "Dine-i...     €    NaN
# 2  {"Service options": {"Outdoor seating": true, ...    €€    NaN
#
#                                                 logo description  verified  \
# 0  https://lh3.googleusercontent.com/-57mb-s1US0w...         NaN       1.0
# 1                                                NaN         NaN       0.0
# 2  https://lh6.googleusercontent.com/-dky986dbAPo...         NaN       1.0
#
#                 owner_id                                        owner_title  \
# 0  117181584539908212891                          Restaurant Zum Schiffchen
# 1                    NaN                                     Zum Kochlöffel
# 2  111611767742001152293  BLOCK HOUSE Düsseldorf Hauptbahnhof Harkortstraße
#
#                                           owner_link reservation_links  \
# 0  https://www.google.com/maps/contrib/1171815845...               NaN
# 1                                                NaN               NaN
# 2  https://www.google.com/maps/contrib/1116117677...               NaN
#
#   booking_appointment_link  menu_link order_links  \
# 0                      NaN        NaN         NaN
# 1                      NaN        NaN         NaN
# 2                      NaN        NaN         NaN
#
#                                        location_link  \
# 0  https://www.google.com/maps/place/Restaurant+Z...
# 1  https://www.google.com/maps/place/Zum+Kochl%C3...
# 2  https://www.google.com/maps/place/BLOCK+HOUSE+...
#
#                       place_id                              google_id  \
# 0  ChIJdfp4DzHKuEcRZfa1cQU-eT8  0x47b8ca310f78fa75:0x3f793e0571b5f665
# 1  ChIJ7zsnfTDKuEcRfy0611XzbqE  0x47b8ca307d273bef:0xa16ef355d73a2d7f
# 2  ChIJm5X1eEfLuEcRseySaZn3Aps  0x47b8cb4778f5959b:0x9b02f7996992ecb1
#
#                     cid             reviews_id located_google_id
# 0   4573755089674958437  4573755089674958336.0               NaN
# 1  11632502437553253759 -6814241636156297216.0               NaN
# 2  11169762264105544881 -7276981809604005888.0               NaN

# %%
# looking to confirm the range of values in rating - range from 1 to 5, nothing below 1
r=cities['rating'].unique()
print(sorted(r))
# Out:
# [nan, 1.0, 1.2, 1.3, 1.7, 1.8, 2.0, 2.1, 2.2, 2.3, 2.5, 2.6, 2.7, 2.8, 2.9, 3.0, 3.1, 3.2, 3.3, 3.4, 3.5, 3.6, 3.7, 3.8, 3.9, 4.0, 4.1, 4.2, 4.3, 4.4, 4.5, 4.6, 4.7, 4.8, 4.9, 5.0]

# %% [markdown]
# Below, I am checking overall df info, I expect to see a few NaN values:
#
# **NOTE:** Below is commented out and output cleared as it is a big frame of text

# %%
# cities.info()

# %% [markdown]
# I wanted to see how many restaurants per city have no reviews, as there are in total for all DFs about 300.
#
# **Note:** I actually ran the below after cleaning and concatenating my data to have accurate counts.

# %%
# test = cities[cities['rating'].isna()==True]
# test['city'].value_counts()

# %% [markdown]
# ## First conclusions on my data
# Drew some conclusions on my overall data from the above.
#
# 1) I Decided that I would have to drop a majority of columns as they don't present any conceivable value to my analyses, some are also essentially duplicating information present in other cols. More on my drop/keep decisions further below.
#
# 2) **Rating** is an average review score. Google Maps users can review starting with 1 as the poorest score in set intervals of +1 up to 5 for top score.
#
# 3) **Reviews** tells us how many reviews a restaurant has on GMaps.
#
# 4) **reviews_per_score 1 thru 5** give us the number of reviews that awarded the according score. These are all valuable insights.
#
# I expected to see a few NaN values, especially in **reviews** - we have about 300 restaurants accross all cities with no reviews. To decide how to treat these 300 rows I checked the value counts of nan values in rating contrasted by city. As a result I saw that it is fairly balanced, with Amsterdam having the largest count of unrated establishments at 54, and Lisbon having the least at 11. Given that this won't cause a severe imbalance in my dataset I decided to drop these rows. Other options I considered as an alternative but waved aside:
#
# - Fill rating with the average for that city and reviews with 0
# - Fill rating with 5 (give the restaurant the benefit of the doubt) reviews with 0 (which would balance out the 5 in rating
# - Fill rating and reviews with 0, which would balance it too low however.
#
# Very concerning to see 113 rows of restaurants without an address, city or country. Exploring some of these locales further, I see that we are mostly dealing with food trucks, or delivery-only businesses that have no seating options. We can turn NaN values for address to 'no address' but will have to somehow substiute NaN values for city and country to allocate these businesses to the actual city they are based in.
#
# - to do so, I decided the best course of action is to go back to my individual city dfs and substitute the missing city and country values at that level where it is easiest
# - I also discovered that for several cities we don't exclusively have all restaurants in their city, but some are what appear to be suburbs, or the city outskirts - and in the case of 'España' perhaps even a mistake. To remove these outliers and errors and make it purely a competition of the 10 actual cities, I went back to my cleaning function and made sure that all values for the column 'city' e.g. for the Lisbon df are overriden by 'Lisbon' only.

# %% [markdown]
# ### Cells to drop
# We have 59 columns in total, but most don't make sense for our further data processing or have duplicated information.
#
# | Column Name | Drop or Keep and why |
# | :---------- | :------------------- |
# | query | drop, refers to the query from outscraper to GMaps |
# | name | keep |
# | site | drop |
# | type | keep |
# | subtypes | drop |
# | category | drop |
# | phone | drop |
# | full_address | keep |
# | borough | drop, too many NaNs and overall not that useful |
# | street | drop |
# | city | keep |
# | postal_code | drop |
# | state | drop |
# | us_state | drop |
# | country | keep |
# | country_code | drop |
# | latitude | keep (for now), may be needed when plotting location on a map |
# | longitude | keep (for now), may be needed when plotting location on a map |
# | time_zone | drop |
# | plus_code | drop, use case unknown |
# | area_service | drop, use case unknown |
# | rating | keep, aggregate review score |
# | reviews | keep, number of reviews |
# | reviews_link | drop |
# | reviews_tags | drop, use case unknown |
# | reviews_per_score | drop, duplicate |
# | reviews_per_score_1 | keep (for now), could be useful |
# | reviews_per_score_2 | keep (for now), could be useful |
# | reviews_per_score_2 | keep (for now), could be useful |
# | reviews_per_score_3 | keep (for now), could be useful |
# | reviews_per_score_4 | keep (for now), could be useful |
# | reviews_per_score_5 | keep (for now), could be useful |
# | photos_count | drop |
# | photo | drop |
# | street_view | drop |
# | located_in | drop |
# | working_hours | drop |
# | working_hours_old_format | drop |
# | other_hours | drop |
# | popular_times | drop |
# | business_status | drop |
# | about | drop |
# | range | keep, 50% Nans, but interesting nevertheless - depicts average price of establishment, range of € to €€€€ from least to most expensive |
# | posts | drop |
# | logo | drop |
# | description | drop |
# | verified | drop |
# | owner_id | drop |
# | owner_title | drop |
# | owner_link | drop |
# | reservation_links | drop |
# | booking_appointment_link | drop |
# | menu_link | drop |
# | order_links | drop |
# | location_link | drop |
# | place_id | drop |
# | google_id | drop |
# | cid | drop |
# | reviews_id | drop |
# | located_google_id | drop |

# %% [markdown]
# **Filtering out locations that are NOT businesses which serve or deliver food**
#
# Checking the 'type' column using .value_counts() revealed that a considerable number (nearly 700 rows) of businesses are in fact NOT serving food. The list includes some closely related businesses like grocery and butcher shops, caterers, a banquet hall and a cooking school - but sadly also some hair raising errors, like electronics manufacturers, a chamber of commerce or a shipping and mailing service...
#
# Parsing the list of unique values I created the type_keywords list below with all businesses that should (subjectively) serve food - like 'restaurant', 'cafe', 'takeaway', and also 'bakery', or 'hotel'. My methodology here was to include any business that you would spontaneously look up for food (included bars and pubs - even though food may be secondary in those cases; but excluding caterers, dance clubs, banquet hall, etc.)
#
# Even though losing nearly 700 rows is a tough pill to swallow, I definetely need to cut all non-dining related rows as they are NOT what I set out to analyse. But add to that the near 300 rows (while some may overlap) I'll drop over having no reviews and I will loose close to 1000 data points. But, again, they are irrelevant, so it can't be helped.
#
# **Note:** Frustratingly, I realised this discrepancy way too late when I calculated my results and got caterers in my top five for Amsterdam... Going forward I will make sure to check columns like these from the get go!

# %%
# # check value counts in type, WARNING: Over 400 values, commented out!

# cities['type'].value_counts()

# %%
# list of keywords to filter the type column

type_keywords = ['Cafe','Café','restaurant','Restaurant','takeaway','shop','Shop','Take Away','Take away','Crêperie','Japanese delicatessen','cafe','deli','Beer hall','Brewpub','Food court','Poke bar','Brewery','Wine bar','Tea house','Coffee store','Cafeteria','delivery','diner','Beer garden','Patisserie','Grill','Gastropub','Café','Brasserie','Meal delivery','Pub','Bakery','Hotel']

# %%
# # code to filter type column according to predefined keywords list 
# # commented out as I incorporated it in my DF cleanup functions 

# # first need to fill nan rows in this column, instead of removing them - I fill with Restaurant (giving them the benefit of the doubt, but oh well)
# cities['type'].fillna('Restaurant', inplace=True)

# cities = cities[cities['type'].str.contains('|'.join(type_keywords))]

# %%
# # obtain column headers for copy/paste and to print a markdown table
# header = []
# for col in cities.columns:
#     #print(col)
#     #print('|',col,'||')
#     header.append(col)
# header

# %% [markdown]
# #### Cleaning Individual City DFs & Concatenating

# %%
# quick function to my dus DF, needs to be separate because of the mismatching column count

def properdata_dus(df):
    
    # below fills empty address cells with none
    df['full_address'] = df['full_address'].fillna('none')
    
    # below fills every city/country cells with the mode, which will be the respective city, e.g. Dus and DE
    df['city'] = df['city'].mode()[0]
    df['country'] = df['country'].mode()[0]
    
    # below drops all columns I decided to omit, !!NOTE!! Except 'area_service' which is not a column in the dus DF
    df=df.drop(['query','site','subtypes','category','phone','borough','street','postal_code','state','us_state','country_code','time_zone','plus_code','reviews_link','reviews_tags','reviews_per_score','photos_count','photo','street_view','located_in','working_hours','working_hours_old_format','other_hours','popular_times','business_status','about','posts','logo','description','verified','owner_id','owner_title','owner_link','reservation_links','booking_appointment_link','menu_link','order_links','location_link','place_id','google_id','cid','reviews_id','located_google_id'],axis=1)

    # incorporated code to filter non-dining locations
    df['type'].fillna('Restaurant', inplace=True)
    df = df[df['type'].str.contains('|'.join(type_keywords))]
    
    # below drops all rows with no reviews/ratings
    df = df.dropna(subset=['rating']) 
    
    return df

# %%
# applying function to dus

dus=properdata_dus(dus)

# %%
# quick function to process all remaining city DFs

def properdata_all(df):
    
    # below fills empty address cells with none
    df['full_address'] = df['full_address'].fillna('none')
    
    # below fills every city/country cells with the mode, which will be the respective city, e.g. Dus and DE
    df['city'] = df['city'].mode()[0]
    df['country'] = df['country'].mode()[0]
    
    # below drops all columns I decided to omit
    df=df.drop(['query','site','subtypes','category','phone','borough','street','postal_code','state','us_state','country_code','time_zone','plus_code','area_service','reviews_link','reviews_tags','reviews_per_score','photos_count','photo','street_view','located_in','working_hours','working_hours_old_format','other_hours','popular_times','business_status','about','posts','logo','description','verified','owner_id','owner_title','owner_link','reservation_links','booking_appointment_link','menu_link','order_links','location_link','place_id','google_id','cid','reviews_id','located_google_id'],axis=1)
    
    # incorporated code to filter non-dining locations
    df['type'].fillna('Restaurant', inplace=True)
    df = df[df['type'].str.contains('|'.join(type_keywords))]
    
    # below drops all rows with no reviews/ratings
    df = df.dropna(subset=['rating'])
    
    return df

# %%
# applying function to all city dfs

bcn=properdata_all(bcn)
ber=properdata_all(ber)
lis=properdata_all(lis)
lnd=properdata_all(lnd)
ams=properdata_all(ams)
mil=properdata_all(mil)
zrh=properdata_all(zrh)
ist=properdata_all(ist)
par=properdata_all(par)

# %%
# rechecking the individual df shapes for conformity

df_lst = [dus, bcn, ber, lis, lnd, ams, mil, zrh, ist, par]

all_shapes()
# Out:
# dus (441, 15)
# bcn (388, 15)
# ber (373, 15)
# lis (454, 15)
# lnd (437, 15)
# ams (363, 15)
# mil (419, 15)
# zrh (410, 15)
# ist (451, 15)
# par (380, 15)

# %%
# # below calculation to get me insight on number of reviews by city for something I had tried out in my results.
# # commented out as I have no use for it, but kept it in case I need it again

# for df in df_lst:
#     print(city_code(df), df['reviews'].describe(), '''
#     ''')

# %% [markdown]
# In removing rows that were not specifically businesses serving food we created some imbalance in imbalance in the number of values for each contestant city and it changed my changed the rank of some cities when compared to my results I had before doing this drop.
#
# While the imbalance in df.shapes is unfortunate, this step has been necessary to ensure that the end result is not influenced by values that should not be part of the equation.

# %%
# double check that transformation worked on mil which had the most missing address values
mil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 419 entries, 0 to 499
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 419 non-null    object
#  1   type                 419 non-null    object
#  2   full_address         419 non-null    object
#  3   city                 419 non-null    object
#  4   country              419 non-null    object
#  5   latitude             419 non-null    float64
#  6   longitude            419 non-null    float64
#  7   rating               419 non-null    float64
#  8   reviews              419 non-null    float64
#  9   reviews_per_score_1  419 non-null    float64
#  10  reviews_per_score_2  419 non-null    float64
#  11  reviews_per_score_3  419 non-null    float64
#  12  reviews_per_score_4  419 non-null    float64
#  13  reviews_per_score_5  419 non-null    float64
#  14  range                265 non-null    object
# dtypes: float64(9), object(6)
# memory usage: 52.4+ KB

# %%
# Concatenating all indidvidual city DFs and override cities 
cities = pd.concat([dus, bcn, ber, lis, lnd, ams, mil, zrh, ist, par], axis=0)

# shape, head and tail to check if successful
print(cities.shape)
display(cities.head(5))
cities.tail(5)
# Out:
# (4116, 15)
#                                                 name  \
# 0                          Restaurant Zum Schiffchen
# 1                                     Zum Kochlöffel
# 2  BLOCK HOUSE Düsseldorf Hauptbahnhof Harkortstraße
# 3                          Restaurant Schwarzes Meer
# 4                                Restaurant Da Bruno
#
#                        type                                 full_address  \
# 0                Restaurant   Konrad-Adenauer-Platz 14, 40210 Düsseldorf
# 1                Restaurant  Friedrich-Ebert-Straße 41, 40210 Düsseldorf
# 2                Restaurant            Harkortstraße 8, 40210 Düsseldorf
# 3  Mediterranean restaurant       Graf-Adolf-Straße 60, 40210 Düsseldorf
# 4        Italian restaurant              Karlstraße 16, 40210 Düsseldorf
#
#          city  country   latitude  longitude  rating  reviews  \
# 0  Düsseldorf  Germany  51.220276   6.792887     3.5    251.0
# 1  Düsseldorf  Germany  51.221250   6.789820     4.5    116.0
# 2  Düsseldorf  Germany  51.219459   6.792052     4.5    135.0
# 3  Düsseldorf  Germany  51.219053   6.784689     4.2    686.0
# 4  Düsseldorf  Germany  51.220369   6.789014     4.6    425.0
#
#    reviews_per_score_1  reviews_per_score_2  reviews_per_score_3  \
# 0                 39.0                 17.0                 43.0
# 1                  0.0                  2.0                  9.0
# 2                  8.0                  3.0                  5.0
# 3                 59.0                 33.0                 51.0
# 4                  9.0                  3.0                 25.0
#
#    reviews_per_score_4  reviews_per_score_5 range
# 0                 73.0                 79.0    €€
# 1                 29.0                 76.0     €
# 2                 22.0                 97.0    €€
# 3                112.0                431.0    €€
# 4                 67.0                321.0    €€
#                  name              type  \
# 493  Starbucks Louvre       Coffee shop
# 494      Shang Palace  Asian restaurant
# 495    Télescope Café              Cafe
# 496           Ladurée       Pastry shop
# 499     Mister Garden        Salad shop
#
#                                           full_address   city country  \
# 493  Musée du louvre En mezzanine, sous la pyramide...  Paris  France
# 494                         10 Av. d'Iéna, 75116 Paris  Paris  France
# 495                         5 Rue Villédo, 75001 Paris  Paris  France
# 496  Carrousel du Louvre, 99 Rue de Rivoli Emplacem...  Paris  France
# 499           4 Rue du Commandant Rivière, 75008 Paris  Paris  France
#
#       latitude  longitude  rating  reviews  reviews_per_score_1  \
# 493  48.861085   2.335902     3.5     49.0                 11.0
# 494  48.863726   2.293400     4.5    337.0                 14.0
# 495  48.866184   2.336358     4.5    146.0                 13.0
# 496  48.861784   2.334326     4.3    128.0                  6.0
# 499  48.872846   2.309471     3.9    124.0                 15.0
#
#      reviews_per_score_2  reviews_per_score_3  reviews_per_score_4  \
# 493                  3.0                  5.0                 12.0
# 494                 11.0                 17.0                 50.0
# 495                  2.0                  7.0                  7.0
# 496                  4.0                  9.0                 30.0
# 499                  4.0                  9.0                 42.0
#
#      reviews_per_score_5 range
# 493                 18.0    €€
# 494                245.0   NaN
# 495                117.0   NaN
# 496                 79.0   €€€
# 499                 54.0   NaN

# %%
cities['type'].value_counts()
# Out:
# Restaurant             1297
# Italian restaurant      228
# Cafe                    173
# French restaurant       123
# Pizza restaurant        107
#                        ...
# Eclectic restaurant       1
# English restaurant        1
# Georgian restaurant       1
# Hoagie restaurant         1
# Noodle shop               1
# Name: type, Length: 225, dtype: int64

# %% [markdown]
# ## SQL Migration
# My column headers are already in the proper format, no need to edit those. As requested by Ironhack for my mid-bootcamp project, I will now migrate my table to mySQL (where I separateld created a 'mid_btcmp_project' database), then copy it back into this Jupyter Notebook.
#
# **NOTE:** below cells are commented out so as to not run them repeatedly if I were to restart the kernel and run all cells again. They confirm to work and have been previously executed.

# %%
# exporting df to .csv for safekeeping
cities.to_csv('All_Cities.csv', index=False)

# %%
# cities.to_sql('all_cities', engine, index=False)
# Out:
# 4116

# %% [markdown]
# ### SQL Re-import

# %%
# query = '''SELECT * FROM mid_btcmp_project.all_cities;'''

# data = pd.read_sql_query(query, engine)
# data.head()
# Out:
#                                                 name  \
# 0                          Restaurant Zum Schiffchen
# 1                                     Zum Kochlöffel
# 2  BLOCK HOUSE Düsseldorf Hauptbahnhof Harkortstraße
# 3                          Restaurant Schwarzes Meer
# 4                                Restaurant Da Bruno
#
#                        type                                 full_address  \
# 0                Restaurant   Konrad-Adenauer-Platz 14, 40210 Düsseldorf
# 1                Restaurant  Friedrich-Ebert-Straße 41, 40210 Düsseldorf
# 2                Restaurant            Harkortstraße 8, 40210 Düsseldorf
# 3  Mediterranean restaurant       Graf-Adolf-Straße 60, 40210 Düsseldorf
# 4        Italian restaurant              Karlstraße 16, 40210 Düsseldorf
#
#          city  country   latitude  longitude  rating  reviews  \
# 0  Düsseldorf  Germany  51.220276   6.792887     3.5    251.0
# 1  Düsseldorf  Germany  51.221250   6.789820     4.5    116.0
# 2  Düsseldorf  Germany  51.219459   6.792052     4.5    135.0
# 3  Düsseldorf  Germany  51.219053   6.784689     4.2    686.0
# 4  Düsseldorf  Germany  51.220369   6.789014     4.6    425.0
#
#    reviews_per_score_1  reviews_per_score_2  reviews_per_score_3  \
# 0                 39.0                 17.0                 43.0
# 1                  0.0                  2.0                  9.0
# 2                  8.0                  3.0                  5.0
# 3                 59.0                 33.0                 51.0
# 4                  9.0                  3.0                 25.0
#
#    reviews_per_score_4  reviews_per_score_5 range
# 0                 73.0                 79.0    €€
# 1                 29.0                 76.0     €
# 2                 22.0                 97.0    €€
# 3                112.0                431.0    €€
# 4                 67.0                321.0    €€

# %% [markdown]
# ## Further Conclusions - SAVEPOINT
#
# Range is about 50% NaN values but still interesting to draw further conclusions on pricing levels in a respective city. Should be binned to 4 levels from cheap to expensive according to numbers of €s. To do so I will still need to drop it from my main cities DF, into a separate DF I will title pricing.
#
# I see two options to process the rating and obtain the overall best restaurants - will try approach 2 first:
# 1. I create a ratio between rating and reviews - disregard reviews_per_score columns
# 2. Disregard rating and reviews column and instead process reviews_per_score columns

# %%
# # Savepoint: re-import cleaned DF in case I need to start over from here
# cities = pd.read_csv('All_Cities.csv')

# %% [markdown]
# ### Further Data Cleanup

# %% [markdown]
# #### Creating pricing DF

# %%
# # obtain column headers for copy/paste and to print a markdown table
# header = []
# for col in cities.columns:
#     #print(col)
#     #print('|',col,'||')
#     header.append(col)
# header

# %%
pricing = cities.filter(['name','city','country','latitude','longitude','rating','range'],axis=1).copy()
print(pricing.shape)
display(pricing.head(2))
# Out:
# (4116, 7)
#                         name        city  country   latitude  longitude  \
# 0  Restaurant Zum Schiffchen  Düsseldorf  Germany  51.220276   6.792887
# 1             Zum Kochlöffel  Düsseldorf  Germany  51.221250   6.789820
#
#    rating range
# 0     3.5    €€
# 1     4.5     €

# %% [markdown]
# ### High Correlation of Values
#
# Of course, reviews and the reviews per score columns are highly correlated as seen below. What the matrix does not capture however is the correlation of the aformentioned values to rating, which is the average of the count of reviews per score and therefore also highly related.
#
# This tells me that my dataset is not going to benefit from modeling, as I have no reasonable y value to model against. Instead, my questions should all be answerable with a bit of number crunching here and graphing it out in Tableau.

# %%
correlations_matrix = cities.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.show()

# %% [markdown]
# ## Which competing city will win the title 'Gourmet Capital of Europe'?

# %% [markdown]
# After some thought on how to best obtain this result with the power of math, a simple weighted average of each city's restaurant ratings measured according to that restaurant's number of reviews seemed ideal.

# %%
def winning_city(df, rtng, rvws):
    return round(sum(df[rvws] * df[rtng]) / df[rvws].sum(), 3) 
    # rounded to 3 decimal places, as otherwise at 2 London/Zurich share a score and London gets alphabetically sorted first

cities_ranked = cities.groupby('city').apply(winning_city, 'rating', 'reviews')
cities_ranked = cities_ranked.sort_values(ascending=False).reset_index()
cities_ranked = cities_ranked.rename(columns={0:"cumulative_score",1:"city"})
cities_ranked.index += 1 
cities_ranked
# Out:
#           city  cumulative_score
# 1       Lisbon             4.365
# 2       London             4.327
# 3       Zürich             4.321
# 4       Berlin             4.316
# 5   Düsseldorf             4.280
# 6    Barcelona             4.277
# 7    Amsterdam             4.248
# 8        Paris             4.165
# 9     İstanbul             4.161
# 10       Milan             4.128

# %% [markdown]
# **Congratulations to Lisbon!**
#
# It has been a very close race London, Zurich and Berlin are not far behind.
#
# Dusseldorf's ranking in the top five was a modest surprise to me!
#
# The bottom five were also surprising! Istanbul was a bit of an unknown variable to me as I know little of that city's food scene. In all honesty, I expected A'dam to rank lower than it did. But Paris low rank and especially Milan's ranking in dead-last place came unexpected! Though Italian's are known to rate food not made by their Mother quite harshly, so...

# %%
# export to .csv for extrapolation in Tableau

cities_ranked.to_csv('cities_ranked.csv', index=False)

# %% [markdown]
# ## What is the probability of having a positive dining experience by randomly selecting any restaurant in our contestant cities?

# %% [markdown]
# If you were to pick any random restaurant without preconceptions in either city, what is the probability of you having a good experience?

# %% [markdown]
# Sadly dind't get around to this in time for the presentation on Friday. Will try to come back to this possibly over the weekend.

# %% [markdown]
# ## Which restaurants are the best in each city?

# %% [markdown]
# Let's find each city's top eateries! Maybe we'll have some surprises in store?
#
# Not as simple as I first thought... The below results from a lot of experimentation not shown:

# %%
# new df that drops any restaurants with a rating below 4, this ensures our top listing would exclude
# restaurants that have a high number of ratings with a score below 4 (one example that popped up was a
# BK in A'dam with a 3,9 rating and several thousands of reviews. Who reviews a fast food chain joint?) 

highest = cities[cities.rating >= 4].copy()

# %%
highest.shape
# Out:
# (3429, 15)

# %%
pd.set_option('display.max_rows', 100)

# %%
topten = highest.groupby('city').apply(lambda x: x.nlargest(10, ['reviews','rating'])).reset_index(level=1, drop=1)

# %%
topten
# Out:
#                                                          name  \
# city
# Amsterdam                            Hard Rock Cafe Amsterdam
# Amsterdam                                               Pllek
# Amsterdam                                         A'DAM Tower
# Amsterdam              Leonardo Hotel Amsterdam Rembrandtpark
# Amsterdam                                   Noorderlicht Café
# Amsterdam                                      Excalibur Café
# Amsterdam                                   XO Hotels Couture
# Amsterdam                             THE BUTCHER Social Club
# Amsterdam                   Camperduin Strandpaviljoen STRUIN
# Amsterdam                    The Student Hotel Amsterdam West
# Barcelona                                          Maremagnum
# Barcelona                                      Hard Rock Cafe
# Barcelona                                           Flax&Kale
# Barcelona                        Centre Comercial El Triangle
# Barcelona                                            7 Portes
# Barcelona                                    Colom Restaurant
# Barcelona                                            La Fonda
# Barcelona                                           Els 4Gats
# Barcelona                              L'Ovella Negra Ramblas
# Barcelona                                       Teresa Carles
# Berlin                                         Hard Rock Cafe
# Berlin                          Restaurant Maximilians Berlin
# Berlin                                 Rausch Schokoladenhaus
# Berlin                                                  AMRIT
# Berlin                                                  Amrit
# Berlin         Dreh-Restaurant Sphere im Berliner Fernsehturm
# Berlin                                                 Cocolo
# Berlin                                  House of Small Wonder
# Berlin                                      Hotel nhow Berlin
# Berlin                            AMRIT Restaurant Schoneberg
# Düsseldorf                                   KÖ Shopping Mall
# Düsseldorf                                             Uerige
# Düsseldorf                                             Takumi
# Düsseldorf                             Okinii Düsseldorf City
# Düsseldorf                              Kasematten Düsseldorf
# Düsseldorf                                        What's Beef
# Düsseldorf                             Naniwa Noodles & Soups
# Düsseldorf                             Hotel Nikko Düsseldorf
# Düsseldorf                                      Maritim Hotel
# Düsseldorf                  Shopping mall
# Düsseldorf                        Brewpub
# Düsseldorf               Ramen restaurant
# Düsseldorf               Sushi restaurant
# Düsseldorf                     Restaurant
# Düsseldorf           Hamburger restaurant
# Düsseldorf  Authentic Japanese restaurant
# Düsseldorf                          Hotel
# Düsseldorf                          Hotel
# Düsseldorf                     Restaurant
# Lisbon                         Food court
# Lisbon                      Shopping mall
# Lisbon                 Seafood restaurant
# Lisbon                 Mexican restaurant
# Lisbon                         Restaurant
# Lisbon                               Cafe
# Lisbon                         Restaurant
# Lisbon                         Restaurant
# Lisbon                              Hotel
# Lisbon                   Sushi restaurant
# London                         Restaurant
# London                         Restaurant
# London                         Restaurant
# London                American restaurant
# London         Modern European restaurant
# London                Japanese restaurant
# London                              Hotel
# London         Modern European restaurant
# London                 Turkish restaurant
# London         Modern European restaurant
# Milan                    Pizza restaurant
# Milan                    Pizza restaurant
# Milan                    Pizza restaurant
# Milan                    Pizza restaurant
# Milan                    Pizza restaurant
# Milan                    Pizza restaurant
# Milan                Breakfast restaurant
# Milan             Small plates restaurant
# Milan                          Restaurant
# Milan                    Greek restaurant
# Paris                   French restaurant
# Paris                   French restaurant
# Paris                           Brasserie
# Paris                   French restaurant
# Paris                   French restaurant
# Paris       Authentic Japanese restaurant
# Paris              Fine dining restaurant
# Paris                   French restaurant
# Paris                    Ramen restaurant
# Paris                 Japanese restaurant
# Zürich                   Swiss restaurant
# Zürich                         Restaurant
# Zürich                         Restaurant
# Zürich                   Swiss restaurant
# Zürich                   Swiss restaurant
# Zürich              Vegetarian restaurant
# Zürich                          Beer hall
# Zürich               Hamburger restaurant
# Zürich                   Swiss restaurant
# Zürich                         Restaurant
# İstanbul                    Shopping mall
# İstanbul                       Restaurant
# İstanbul                       Restaurant
# İstanbul                       Restaurant
# İstanbul                    Shopping mall
# İstanbul                    Shopping mall
# İstanbul             Hamburger restaurant
# İstanbul           Doner kebab restaurant
# İstanbul                       Kebab shop
# İstanbul                            Hotel
#
#                                                  full_address        city  \
# city
# Amsterdam              Max Euweplein 57-61, 1017 MA Amsterdam   Amsterdam
# Amsterdam              T.T. Neveritaweg 59, 1033 WB Amsterdam   Amsterdam
# Amsterdam                 Overhoeksplein 1, 1031 KS Amsterdam   Amsterdam
# Amsterdam            Staalmeesterslaan 410, 1057 PH Amsterdam   Amsterdam
# Amsterdam                   NDSM-Plein 102, 1033 WB Amsterdam   Amsterdam
# Amsterdam       Oudezijds Achterburgwal 48, 1012 DP Amsterdam   Amsterdam
# Amsterdam                  Delflandlaan 15, 1062 EA Amsterdam   Amsterdam
# Amsterdam                 Overhoeksplein 1, 1031 KS Amsterdam   Amsterdam
# Amsterdam                       Heereweg 407, 1871 GL Schoorl   Amsterdam
# Amsterdam   van de Sande Bakhuijzenstraat 4, 1061 AG Amste...   Amsterdam
# Barcelona                  Moll d'Espanya, 5, 08039 Barcelona   Barcelona
# Barcelona               Pl. de Catalunya, 21, 08002 Barcelona   Barcelona
# Barcelona           Carrer dels Tallers, 74b, 08001 Barcelona   Barcelona
# Zürich                    163.0                632.0               2503.0
# Zürich                    100.0                364.0               1376.0
# Zürich                     80.0                313.0               1412.0
# Zürich                     92.0                288.0               1094.0
# Zürich                    105.0                322.0                994.0
# Zürich                     46.0                202.0                879.0
# Zürich                     74.0                291.0                844.0
# Zürich                     80.0                285.0                801.0
# Zürich                     70.0                331.0                950.0
# Zürich                     26.0                 93.0                333.0
# İstanbul                  556.0               2247.0               6088.0
# İstanbul                  231.0                865.0               2095.0
# İstanbul                  301.0                709.0               1386.0
# İstanbul                  151.0                440.0               1369.0
# İstanbul                  268.0                953.0               1665.0
# İstanbul                  121.0                433.0               1202.0
# İstanbul                  124.0                421.0               1054.0
# İstanbul                  132.0                465.0               1138.0
# İstanbul                  121.0                342.0               1035.0
# İstanbul                  120.0                331.0                887.0
#
#             reviews_per_score_5 range
# city
# Amsterdam                9993.0   €€€
# Amsterdam                4201.0    €€
# Amsterdam                4372.0   NaN
# Amsterdam                1888.0   NaN
# Amsterdam                1841.0    €€
# Amsterdam                2177.0    €€
# Amsterdam                1673.0   NaN
# Amsterdam                1370.0    €€
# Amsterdam                1115.0   NaN
# Amsterdam                1183.0   NaN
# Barcelona               16385.0    €€
# Barcelona                9965.0    €€
# Barcelona                5088.0    €€
# Barcelona                2956.0   NaN
# Barcelona                4021.0   €€€
# Barcelona                6059.0    €€
# Barcelona                2669.0    €€
# Barcelona                2583.0    €€
# Barcelona                2593.0     €
# Barcelona                3299.0    €€
# Berlin                   8419.0    €€
# Berlin                   3810.0    €€
# Berlin                   4869.0   NaN
# Berlin                   3488.0    €€
# Berlin                   2977.0    €€
# Berlin                   2862.0   €€€
# Berlin                   2756.0    €€
# Berlin                   2337.0    €€
# Berlin                   1992.0   NaN
# Berlin                   2063.0    €€
# Düsseldorf               6154.0   NaN
# Düsseldorf               6633.0    €€
# Düsseldorf               3887.0    €€
# Düsseldorf               2320.0    €€
# Düsseldorf               1998.0    €€
# Düsseldorf               2161.0    €€
# Düsseldorf               2651.0   NaN
# Düsseldorf               1616.0   NaN
# Düsseldorf               2036.0   NaN
# Düsseldorf               1263.0    €€
# Lisbon                  26279.0   NaN
# Lisbon                  11654.0   NaN
# Lisbon                   8901.0   €€€
# Lisbon                   3441.0    €€
# Lisbon                   5126.0   €€€
# Lisbon                   2559.0    €€
# Lisbon                   1989.0    €€
# Lisbon                   1842.0    €€
# Lisbon                   1885.0   NaN
# Lisbon                   1297.0    €€
# London                  36324.0   NaN
# London                  35155.0   NaN
# London                  20095.0   NaN
# London                   9458.0   £££
# London                   4578.0   £££
# London                   4704.0  ££££
# London                   4053.0   NaN
# London                   2881.0    ££
# London                   3444.0    ££
# London                   3798.0   £££
# Milan                    5477.0    €€
# Milan                    3544.0    €€
# Milan                    3128.0     €
# Milan                    3800.0     €
# Milan                    1571.0    €€
# Milan                    1950.0    €€
# Milan                    1349.0    €€
# Milan                    1526.0    €€
# Milan                    1182.0   NaN
# Milan                    1034.0     €
# Paris                    5989.0   €€€
# Paris                    3941.0   €€€
# Paris                    3346.0   €€€
# Paris                    3267.0   €€€
# Paris                    3044.0   €€€
# Paris                    2504.0     €
# Paris                    2541.0  €€€€
# Paris                    1845.0   €€€
# Paris                    2654.0    €€
# Paris                    2167.0   NaN
# Zürich                   4713.0    $$
# Zürich                   3510.0    $$
# Zürich                   3497.0    $$
# Zürich                   2248.0    $$
# Zürich                   1921.0    $$
# Zürich                   1804.0    $$
# Zürich                   1372.0     $
# Zürich                   1404.0    $$
# Zürich                   1181.0    $$
# Zürich                   2013.0   NaN
# İstanbul                17104.0   NaN
# İstanbul                 6271.0    $$
# İstanbul                 3834.0    $$
# İstanbul                 3950.0    $$
# İstanbul                 2854.0   NaN
# İstanbul                 3777.0   NaN
# İstanbul                 3481.0    $$
# İstanbul                 2879.0    $$
# İstanbul                 2622.0    $$
# İstanbul                 2622.0   NaN

# %%
topten.shape
# Out:
# (100, 15)

# %%
# export to .csv for extrapolation in Tableau

topten.to_csv('top_restaurants.csv', index=False)

# %% [markdown]
# ## City Restaurant Heatmaps - Where am I most likely to find a good restaurant? Are there any clusters?

# %% [markdown]
# This will be solved using Tableau, find my slides here: https://public.tableau.com/app/profile/nicolas.vollmer/viz/NicolasMid-BootcampProjectAGastro-SceneShowdown/Milan?publish=yes
#
# **NOTE:** this is not my latest file (but quite close) as I am no longer able to upload and save the file to Tableau public - I only get error messages. I think it may have something to do with the filesized causing issues.
#
# **PS:** The volume of data (or lack thereof) did not actually lend itself well to creating heatmap stile maps, instead I kept it at dotted map pins.

# %%
# checking an 'outlier' for Paris, i.e. a restaurant that is not actually located in the city, but far outside city limits.

cities.loc[cities['name'] == 'Birdy Miam Miam']
# Out:
#                 name           type full_address   city country   latitude  \
# 195  Birdy Miam Miam  Meal delivery         none  Paris  France  47.028148
#
#      longitude  rating  reviews  reviews_per_score_1  reviews_per_score_2  \
# 195   3.988648     4.1    104.0                 14.0                  6.0
#
#      reviews_per_score_3  reviews_per_score_4  reviews_per_score_5 range
# 195                  4.0                 10.0                 70.0   NaN

# %% [markdown]
# ## Ceap&Cheerful-Meter (TM) - Which restaurants offer the best bang for your buck?

# %% [markdown]
# Sadly dind't get around to this in time for the presentation on Friday. Will try to come back to this possibly over the weekend.

# %% [markdown]
# ## Closing Remarks
# **Final revision from Sunday, Oct. 1 2022**
#
# This excercise has been quite fun for me overall! Though I must report some serious disappointments thrown my way:
# 1. That my data did not really necessitate the use of modeling was both a relief but also quite upsetting. On the one hand, I was seriously scrambled to get the above together in time without having to delve into modeling; but on the other I feel like I was deprived of a valuable learing and practice opportunity...
#
#
# 2. The proportionally large amount of non-restaurant related businesses was a serious bummer, especially because I discovered it way too late and did not take more time to check my data thoroughly at the onset. Getting the data of GMaps just took a looong time and I started way too late and felt I had to forge ahead. In the end, this cost me more time than if I had just done it right and approached the data with more caution.
#
#
# 3. Additionally, visualising the restaurants overlaid on city maps revealed further inconsistencies in the data:
#     - Some restaurants where far outside the city limits for some (not all) of these cities - especially for Paris, Amsterdam and Dusseldorf, one from Paris even appeared in the USA. In the visualisation I was able to filter those out using Tableau.
#     - There were noticeable 'gaps' for each city for which my data did not list any restaurants. Most neighbourhoods in any city would have at least one, if not more restaurant or takeout businesses, so while I did expect 'clustering' around popular going-out areas for each city, I did not expect to see a lot of empty streches of map, or Istanbul, where there is mostly clustering inside the East and West parts of the city, but none inbetween... It is also quite apparent on cities like A'dam, where there are fewer restaurants in the circles around Central Station than I would come to expect. Additionally, my neighbourood in Dusseldorf was missing what is probably one of the better Italian restaurants in the city.
#     - The above points all harken back to my method of data collection. I chalk this up not only to the webscraping tool I used to get my data, but also Google's algorythm that returned results in nearby Cologne when looking for Dus restaurants. I wonder if things would have been different if I had figured out how to scrape GMaps on my own without the tool and potentially collect larger and more complete datasets for each city - 500, especially in larger areas like Paris or London is simply not enough.
#
#
# 4. The entire process was very long-winded and full of distractions - especially my failed attempts in data scraping and needing to ask my classmates to help me get the data from outscraper.com's free test. I feel like having learned some valuable lessons and being much further than when I started this course, but at the same time I still feel to be at the start of a very long road ahead.
#
#
# 5. I spend way too many hours working late into the night this week. I had a serious sleep deficiency...
#
#
# 6. I was not fully satisfied with my calculations to obtain answers to my questions 1) **Which competing city will win the title 'Gourmet Capital of Europe'?** and 3) **Which restaurants are the best in each city?**.
#     1. For "Which competing city will win the title 'Gourmet Capital of Europe'?" I used a simple weighted average, which I believe works quite well, but does give extra weight to restaurants and cities where there are more (positive) restaurant reviews - which would always favour Lissabon, as it simply had the most often reviewed restaurants of the 10 contestants. This extra weight does not matter much, as I believe google restaurant reviews are highly subjective in nature and people most likely will vote at extremes, i.e. 1 or 5, but by democratic principle, the more of these reviews we have, the more clear an image will we have of the actual experience for the reviewed business, hence some weight should be given to a 4,3 restaurant with 18,000 reviews vs. a 4,6 restaurant with only 6,000 reviews. However, this also means that we are probably underweighing a lot of restaurants that are either:
#         - secret pearls: i.e. places that are mostly fantastic, but few people know and talk about
#         - new entrants: i.e. places that have recently opened and could not garner many reviews
#         - expensive/exclusive: i.e. places that less people end up reviewing as fewer may eat there due to high costs, or exclusivity (like Michelin-Starred restaurants with long reservation waitlists).
#     2. Equally, for "Which restaurants are the best in each city?" I had to resort to using a groupby and then filter restaurants by highest number of reviews and secondly their review score. As stated in point A above, this is the best way to interpret this data given the subjective nature, but it yielded 'funny' results: Hard Rock Cafe coming in 1st for both Berlin and Amsterdam (and again 4th for London) as they had they simply had way more positive reviews than anyone else. Had I had more time, I would have liked to fiddle around further with calculating a Bayesian average for this as it might have changed things somehow, or find a different way to calculate.
#
#
# **FINAL NOTE:** A more complete dataset would likely have made a different outcome in my results. Again, quite a few restaurants appear to have been missing at the more suburban level in all cities, and there a lot of outliers, which in this case refers to businesses that could not be considered restaurants (electronics manufacturers, accounting firms... but also supermarkets), as well as a few restaurants that were outliers in the sense that they were not actually located in the city I meant to analse. Actually, cutting the non-restaurant related businesses from the dataset did not change the rating and ranking of both Lissabon and Milan (both respectively remained in first and last place in both cases) but it did shuffle the inbetween rankings of Amsterdam, London and Zurich.
