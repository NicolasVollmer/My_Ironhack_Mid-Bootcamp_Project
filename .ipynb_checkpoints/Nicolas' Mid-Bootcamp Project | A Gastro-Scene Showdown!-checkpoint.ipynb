# %% [markdown]
# # Nicolas' Mid-Bootcamp Project | A Gastro-Scene Showdown!
#
# **WHICH CITY WILL BE CROWNED GOURMET-CAPITAL OF EUROPE?**
#
# We have 500 eateries from 10 exciting cities competing for this most glamourous title! As for our contender selection, I oriented myself by the (European) countries (and cities) of residence of my fellow Ironhack students and from there selected one city (except for Germany) that is sure to offer exciting culinary delights:
# - Dusseldorf, Germany - my city of residence with some fantastic dining options, especially Asian food. But how will it compare to these major contenders? I promise no bias on my part, just stone-cold data wrangling!
# - Amsterdam, Netherlands - some fantastic (international) eateries here, home of the NL Ironhack remote campus. Thankfully the Dutch West India Company imported more than just goods!
# - Barcelona, Spain - Madrid would also be a fantastic choice for restaurants, tough call but Barceló is just a special kind of cool!
# - Berlin, Germany - bringing in a 2nd German contender against this overbearing cosmopolitan competition, chosen because several from my cohort live here, but also as it has what is probably Germany's most experimental restaurant scene.
# - Istambul, Turkey - a major metropol straddling Europe and Asia, a fusion of east and west! We can expect an exciting culinary scene.
# - Lisbon, Portugal - the cultural and political heart of Portugal, would expect nothing short of fantastic here!
# - London, UK - London breaks conventions, not just with the image of British food in general. A real dine-out heavyweight champ!
# - Milan, Italy - no cohorts from Italy afaik, but not a real dining competition without some Italian flair. Chosen over Rome for it's fashion fame and economical strength - recipe for a stellar restaurant scene. Carpe Diem!
# - Paris, France - what pan-european food competition would be complete without some 'joie de vivre'?
# - Zurich, Switzerland - no fellow students from here, chosen for my love of Switzerland and Zurich. Honestly cannot remember ever having had a disappointing meal anywhere in CH.
#
# **INTRODUCTORY NOTE ON DATA METHODOLOGY:**
#
# I had attempted to build a webcrawler to parse Google Maps and scrape restaurant information using Python, but had run into several issues that I was unable to resolve by myself. Instead, I used outscraper.com, an online scraping tool to do the job for me.
#
# Doing so unfortunately limited my sample size to 500 restaurants/rows per city as that was the maximum free query size allowed by the tool. A smaller city target like Dusseldorf or Zurich may or may not actually have around that many restaurants, but major cities like Berlin, Paris or London would likely have far more. Additionally, I had little control over the logic applied by the tool (or rather Google Maps) in giving me my 500 'restaurant' search results per city - though I assume Google would use it's considerable AI clout to deliver results of the most searched/selected/popular restaurants in any given location in descending order. Yet, not all values in each dataset may actually be fully-fledged restaurants - some may be cafés, bakeries or delicacy shops (Et al.) that sell meals.

# %% [markdown]
# #### Imports

# %%
# importing necessary libraries
import pandas as pd
import numpy as np
import glob # for importing all files concatenated together

# %%
# SQL imports
import pymysql
from sqlalchemy import create_engine
import sqlalchemy.types as sql_types
from getpass import getpass

# %%
password = getpass()
# Out:
# ········

# %%
# setting up engine and connection to MySQL - previously created a new SQL database titled mid_btcmp_project
connection_string = 'mysql+pymysql://root:'+password+'@localhost/mid_btcmp_project'
engine = create_engine(connection_string)

# %%
# override limit on max width of df columns
pd.set_option('display.max_columns', None)

# %%
# importing all dataframes individually and checking shape for conformity
dus = pd.read_excel('Datasets/Dusseldorf.xlsx')
print(dus.shape)
bcn = pd.read_excel('Datasets/Barcelona.xlsx')
print(bcn.shape)
ber = pd.read_excel('Datasets/Berlin.xlsx')
print(ber.shape)
lis = pd.read_excel('Datasets/Lisbon.xlsx')
print(lis.shape)
lnd = pd.read_excel('Datasets/London.xlsx')
print(lnd.shape)
ams = pd.read_excel('Datasets/Amsterdam.xlsx')
print(ams.shape)
mil = pd.read_excel('Datasets/Milan.xlsx')
print(mil.shape)
zrh = pd.read_excel('Datasets/Zurich.xlsx')
print(zrh.shape)
ist = pd.read_excel('Datasets/Istambul.xlsx')
print(ist.shape)
par = pd.read_excel('Datasets/Paris.xlsx')
print(par.shape)
# Out:
# (500, 58)
# (500, 59)
# (500, 59)
# (500, 59)
# (500, 59)
# (500, 59)
# (500, 59)
# (500, 59)
# (500, 59)
# (500, 59)

# %%
# noticed that dus oddly has one column less compared to the rest... Checking .head() to find it is missing a column 
# labelled 'area_service' which appears to have no value to our following calculations anyways. 
display(dus.head(1))
bcn.head(1)
# Out:
#                                         query                       name  \
# 0  restaurant, 40210, Nordrhein-Westfalen, DE  Restaurant Zum Schiffchen
# 1  restaurant, 40210, Nordrhein-Westfalen, DE             Zum Kochlöffel
#
#                                       site        type    subtypes  \
# 0  https://www.brauerei-zum-schiffchen.de/  Restaurant  Restaurant
# 1                                      NaN  Restaurant  Restaurant
#
#       category            phone                                 full_address  \
# 0  restaurants  +49 211 1701215   Konrad-Adenauer-Platz 14, 40210 Düsseldorf
# 1  restaurants  +49 211 1609615  Friedrich-Ebert-Straße 41, 40210 Düsseldorf
#
#          borough                     street        city  postal_code  state  \
# 0  Stadtbezirk 1   Konrad-Adenauer-Platz 14  Düsseldorf        40210    NaN
# 1  Stadtbezirk 1  Friedrich-Ebert-Straße 41  Düsseldorf        40210    NaN
#
#    us_state  country country_code   latitude  longitude      time_zone  \
# 0       NaN  Germany           DE  51.220276   6.792887  Europe/Berlin
# 1       NaN  Germany           DE  51.221250   6.789820  Europe/Berlin
#
#    plus_code  rating  reviews  \
# 0        NaN     3.5    251.0
# 1        NaN     4.5    116.0
#
#                                         reviews_link  reviews_tags  \
# 0  https://search.google.com/local/reviews?placei...           NaN
# 1  https://search.google.com/local/reviews?placei...           NaN
#
#                                reviews_per_score  reviews_per_score_1  \
# 0  {"1": 39, "2": 17, "3": 43, "4": 73, "5": 79}                 39.0
# 1     {"1": 0, "2": 2, "3": 9, "4": 29, "5": 76}                  0.0
#
#    reviews_per_score_2  reviews_per_score_3  reviews_per_score_4  \
# 0                 17.0                 43.0                 73.0
# 1                  2.0                  9.0                 29.0
#
#    reviews_per_score_5  photos_count  \
# 0                 79.0         117.0
# 1                 76.0          18.0
#
#                                                photo  \
# 0  https://lh5.googleusercontent.com/p/AF1QipMU8-...
# 1  https://lh5.googleusercontent.com/p/AF1QipNyyl...
#
#                                          street_view located_in  \
# 0  https://lh5.googleusercontent.com/p/AF1QipMU8-...        NaN
# 1  https://lh5.googleusercontent.com/p/AF1QipNyyl...        NaN
#
#                                        working_hours  \
# 0  {"Monday": "8am-11pm", "Tuesday": "8am-11pm", ...
# 1  {"Monday": "6am-5pm", "Tuesday": "6am-5pm", "W...
#
#                             working_hours_old_format other_hours  \
# 0  Monday: 8am-11pm | Tuesday: 8am-11pm | Wednesd...         NaN
# 1  Monday: 6am-5pm | Tuesday: 6am-5pm | Wednesday...         NaN
#
#    popular_times business_status  \
# 0            NaN     OPERATIONAL
# 1            NaN     OPERATIONAL
#
#                                                about range  posts  \
# 0  {"Service options": {"Takeaway": true, "Dine-i...    €€    NaN
# 1  {"Service options": {"Takeaway": true, "Dine-i...     €    NaN
#
#                                                 logo description  verified  \
# 0  https://lh3.googleusercontent.com/-57mb-s1US0w...         NaN      True
# 1                                                NaN         NaN     False
#
#                 owner_id                owner_title  \
# 0  117181584539908212891  Restaurant Zum Schiffchen
# 1                    NaN             Zum Kochlöffel
#
#                                           owner_link reservation_links  \
# 0  https://www.google.com/maps/contrib/1171815845...               NaN
# 1                                                NaN               NaN
#
#   booking_appointment_link  menu_link order_links  \
# 0                      NaN        NaN         NaN
# 1                      NaN        NaN         NaN
#
#                                        location_link  \
# 0  https://www.google.com/maps/place/Restaurant+Z...
# 1  https://www.google.com/maps/place/Zum+Kochl%C3...
#
#                       place_id                              google_id  \
# 0  ChIJdfp4DzHKuEcRZfa1cQU-eT8  0x47b8ca310f78fa75:0x3f793e0571b5f665
# 1  ChIJ7zsnfTDKuEcRfy0611XzbqE  0x47b8ca307d273bef:0xa16ef355d73a2d7f
#
#                     cid    reviews_id located_google_id
# 0   4573755089674958437  4.573755e+18               NaN
# 1  11632502437553253759 -6.814242e+18               NaN
#                              query              name                    site  \
# 0  Restaurant, 08001, Cataluna, ES    RAO Restaurant  http://www.raobcn.com/
# 1  Restaurant, 08001, Cataluna, ES  Asian Restaurant                     NaN
#
#                type                                         subtypes  \
# 0        Restaurant                                       Restaurant
# 1  Asian restaurant  Asian restaurant, Indian restaurant, Restaurant
#
#       category             phone  \
# 0  restaurants  +34 655 59 70 21
# 1  restaurants  +34 933 01 34 67
#
#                                         full_address  borough  \
# 0           Carrer de les Sitges, 3, 08001 Barcelona      NaN
# 1  Carrer de l'Arc de Sant Agustí, 5, 08001 Barce...      NaN
#
#                               street       city  postal_code      state  \
# 0            Carrer de les Sitges, 3  Barcelona       8001.0  Barcelona
# 1  Carrer de l'Arc de Sant Agustí, 5  Barcelona       8001.0  Barcelona
#
#    us_state country country_code   latitude  longitude      time_zone  \
# 0       NaN   Spain           ES  41.384290   2.169572  Europe/Madrid
# 1       NaN   Spain           ES  41.380411   2.172457  Europe/Madrid
#
#    plus_code  area_service  rating  reviews  \
# 0        NaN         False     4.7   1022.0
# 1        NaN         False     4.4    338.0
#
#                                         reviews_link  reviews_tags  \
# 0  https://search.google.com/local/reviews?placei...           NaN
# 1  https://search.google.com/local/reviews?placei...           NaN
#
#                                  reviews_per_score  reviews_per_score_1  \
# 0  {"1": 22, "2": 19, "3": 39, "4": 113, "5": 829}                 22.0
# 1   {"1": 12, "2": 10, "3": 26, "4": 88, "5": 202}                 12.0
#
#    reviews_per_score_2  reviews_per_score_3  reviews_per_score_4  \
# 0                 19.0                 39.0                113.0
# 1                 10.0                 26.0                 88.0
#
#    reviews_per_score_5  photos_count  \
# 0                829.0          1467
# 1                202.0           181
#
#                                                photo  \
# 0  https://lh5.googleusercontent.com/p/AF1QipN8K6...
# 1  https://lh5.googleusercontent.com/p/AF1QipP5ud...
#
#                                          street_view  located_in  \
# 0  https://lh5.googleusercontent.com/p/AF1QipN8K6...         NaN
# 1  https://lh5.googleusercontent.com/p/AF1QipP5ud...         NaN
#
#                                        working_hours  \
# 0  {"Monday": "Closed", "Tuesday": "7PM-12AM", "W...
# 1  {"Monday": "Closed", "Tuesday": "12:30-11:45PM...
#
#                             working_hours_old_format other_hours  \
# 0  Monday: Closed | Tuesday: 7PM-12AM | Wednesday...         NaN
# 1  Monday: Closed | Tuesday: 12:30-11:45PM | Wedn...         NaN
#
#    popular_times business_status  \
# 0            NaN     OPERATIONAL
# 1            NaN     OPERATIONAL
#
#                                                about range  posts  \
# 0  {"Service options": {"Dine-in": true, "Deliver...    €€    NaN
# 1  {"Service options": {"Outdoor seating": true, ...     €    NaN
#
#                                                 logo  \
# 0  https://lh5.googleusercontent.com/-XoQulx74O2Q...
# 1  https://lh4.googleusercontent.com/-5edelM_o-eE...
#
#                                          description  verified  \
# 0  Edgy, brick-walled space with a terrace, servi...      True
# 1                                                NaN      True
#
#                 owner_id       owner_title  \
# 0  108398980134304825937    RAO Restaurant
# 1  104664595703166979865  Asian Restaurant
#
#                                           owner_link  \
# 0  https://www.google.com/maps/contrib/1083989801...
# 1  https://www.google.com/maps/contrib/1046645957...
#
#                                    reservation_links  \
# 0  https://raobcn.com/#!/reservations, https://ww...
# 1                                                NaN
#
#                             booking_appointment_link  menu_link order_links  \
# 0                 https://raobcn.com/#!/reservations        NaN         NaN
# 1  https://www.just-eat.es/restaurants-asian-rest...        NaN         NaN
#
#                                        location_link  \
# 0  https://www.google.com/maps/place/RAO+Restaura...
# 1  https://www.google.com/maps/place/Asian+Restau...
#
#                       place_id                              google_id  \
# 0  ChIJZQKuEx6jpBIRAttn9_8h0Dk  0x12a4a31e13ae0265:0x39d021fff767db02
# 1  ChIJpVe7eliipBIRMs3VTawWbGo  0x12a4a2587abb57a5:0x6a6c16ac4dd5cd32
#
#                    cid    reviews_id  located_google_id
# 0  4165867038568864514  4.165867e+18                NaN
# 1  7668529194801155378  7.668529e+18                NaN

# %%
# df names for copy/paste:
# dus, bcn, ber, lis, lnd, ams, mil, zrh, ist, par

# %%
# to save some time, I instead chose to extract all excel files from my directory together and concat into one df
dataset_folder = glob.glob("Datasets/*.xlsx")
df = pd.concat(pd.read_excel(excelFile) for excelFile in dataset_folder)
df
# Out:
# /var/folders/yb/h9hkbtf17cq8_7fj_jjzdpcm0000gn/T/ipykernel_963/893064041.py:3: FutureWarning: Behavior when concatenating bool-dtype and numeric-dtype arrays is deprecated; in a future version these will cast to object dtype (instead of coercing bools to numeric values). To retain the old behavior, explicitly cast bool-dtype arrays to numeric dtype.
#   df = pd.concat(pd.read_excel(excelFile) for excelFile in dataset_folder)
#                                           query                          name  \
# 0                 restaurant, 12355, Berlin, DE                  DE Americano
# 1                 restaurant, 12355, Berlin, DE      Casino am Zwickauer Damm
# 2                 restaurant, 12355, Berlin, DE                Zum Alten Krug
# 3                 restaurant, 12355, Berlin, DE  Villa Toscana - Rudow Berlin
# 4                 restaurant, 12355, Berlin, DE                   Nea Politia
# ..                                          ...                           ...
# 495  restaurant, Bahçelievler, Istanbul, Turkey                       SÜTWEST
# 496  restaurant, Bahçelievler, Istanbul, Turkey  Ömür Plaza Alışveriş Merkezi
# 497  restaurant, Bahçelievler, Istanbul, Turkey                   Otel Atabay
# 498  restaurant, Bahçelievler, Istanbul, Turkey               Kocasinan Hotel
# 499  restaurant, Bahçelievler, Istanbul, Turkey            Green Garden Hotel
#
#                                                   site                type  \
# 0                                                  NaN          Restaurant
# 1                  http://casino-am-zwickauer-damm.de/         Beer garden
# 2                  http://www.zum-alten-krug-rudow.de/   German restaurant
# 3    https://villatoscanaberlin.de/12767?utm_source...  Italian restaurant
# 4                          https://www.nea-politia.de/    Greek restaurant
# ..                                                 ...                 ...
# 495                                                NaN         Pastry shop
# 496                                                NaN       Shopping mall
# 497                      http://www.otelatabay.com.tr/               Hotel
# 498                                                NaN               Hotel
# 499          https://www.greengardenistanbulhotel.com/               Hotel
#
#                                               subtypes              category  \
# 0                                           Restaurant           restaurants
# 1                                          Beer garden           restaurants
# 2               German restaurant, Caterer, Restaurant  Deutsches Restaurant
# 3    Italian restaurant, Grocery delivery service, ...           restaurants
# 4           Greek restaurant, Mediterranean restaurant           restaurants
# ..                                                 ...                   ...
# 495                                        Pastry shop               Pastane
# 496                                      Shopping mall     Alışveriş merkezi
# 497                                              Hotel                hotels
# 498                                              Hotel                hotels
# 499                                              Hotel                hotels
#
#                  phone                                       full_address  \
# 0                  NaN                  Köpenicker Str. 130, 12355 Berlin
# 1      +49 30 92146590                         Str. 231 129, 12355 Berlin
# 2       +49 30 6633022                         Alt-Rudow 59, 12355 Berlin
# 3      +49 30 50342595                  Köpenicker Str. 150, 12355 Berlin
# 4      +49 30 66529229            Lieselotte-Berger-Platz 4, 12355 Berlin
# ..                 ...                                                ...
# 495                NaN  Bahçelievler Merkez, Kültür Sk., 34180 Bahçeli...
# 496  +90 212 575 02 90  Bahçelievler Merkez, Şair Orhan Veli Sk. No:22...
# 497  +90 212 502 52 17  Bahçelievler Merkez, Hanımeli Sk., 34180 Bahçe...
# 498  +90 212 551 39 74  Şirinevler, Adnan Kahveci Blv. No: 9, 34188 Ba...
# 499  +90 212 593 22 44  Şirinevler, İncesu Sk. No 13, 34188 Bahçelievl...
#
#                  borough                     street      city postal_code  \
# 0               Neukölln        Köpenicker Str. 130    Berlin     12355.0
# 1               Neukölln               Str. 231 129    Berlin     12355.0
# 2               Neukölln               Alt-Rudow 59    Berlin     12355.0
# 3               Neukölln        Köpenicker Str. 150    Berlin     12355.0
# 4               Neukölln  Lieselotte-Berger-Platz 4    Berlin     12355.0
# ..                   ...                        ...       ...         ...
# 495  Bahçelievler Merkez                 Kültür Sk.  İstanbul       34180
# 496  Bahçelievler Merkez  Şair Orhan Veli Sk. No:22  İstanbul       34180
# 497  Bahçelievler Merkez               Hanımeli Sk.  İstanbul       34180
# 498           Şirinevler   Adnan Kahveci Blv. No: 9  İstanbul       34188
# 499           Şirinevler           İncesu Sk. No 13  İstanbul       34188
#
#         state  us_state  country country_code   latitude  longitude  \
# 0         NaN       NaN  Germany           DE  52.421340  13.503272
# 1         NaN       NaN  Germany           DE  52.415545  13.470965
# 2         NaN       NaN  Germany           DE  52.417691  13.496142
# 3         NaN       NaN  Germany           DE  52.420180  13.500526
# 4         NaN       NaN  Germany           DE  52.403601  13.506108
# ..        ...       ...      ...          ...        ...        ...
# 495  İstanbul       NaN   Turkey           TR  40.997457  28.860907
# 496  İstanbul       NaN   Turkey           TR  40.998731  28.873760
# 497  İstanbul       NaN   Turkey           TR  41.005627  28.870561
# 498  İstanbul       NaN   Turkey           TR  40.992179  28.846664
# 499  İstanbul       NaN   Turkey           TR  40.993195  28.844299
#
#            time_zone  plus_code area_service  rating  reviews  \
# 0      Europe/Berlin        NaN        False     NaN      NaN
# 1      Europe/Berlin        NaN        False     4.2    144.0
# 2      Europe/Berlin        NaN        False     4.5    755.0
# 3      Europe/Berlin        NaN        False     4.4    714.0
# 4      Europe/Berlin        NaN        False     4.3    754.0
# ..               ...        ...          ...     ...      ...
# 495  Europe/Istanbul        NaN        False     5.0      1.0
# 496  Europe/Istanbul        NaN        False     3.7   7196.0
# 497  Europe/Istanbul        NaN        False     3.7    341.0
# 498  Europe/Istanbul        NaN        False     3.6    107.0
# 499  Europe/Istanbul        NaN        False     4.3    550.0
#
#                                           reviews_link  reviews_tags  \
# 0                                                  NaN           NaN
# 1    https://search.google.com/local/reviews?placei...           NaN
# 2    https://search.google.com/local/reviews?placei...           NaN
# 3    https://search.google.com/local/reviews?placei...           NaN
# 4    https://search.google.com/local/reviews?placei...           NaN
# ..                                                 ...           ...
# 495  https://search.google.com/local/reviews?placei...           NaN
# 496  https://search.google.com/local/reviews?placei...           NaN
# 497  https://search.google.com/local/reviews?placei...           NaN
# 498  https://search.google.com/local/reviews?placei...           NaN
# 499  https://search.google.com/local/reviews?placei...           NaN
#
#                                      reviews_per_score  reviews_per_score_1  \
# 0                                                  NaN                  NaN
# 1          {"1": 8, "2": 7, "3": 12, "4": 41, "5": 76}                  8.0
# 2      {"1": 21, "2": 17, "3": 44, "4": 189, "5": 484}                 21.0
# 3      {"1": 34, "2": 25, "3": 49, "4": 154, "5": 452}                 34.0
# 4      {"1": 37, "2": 15, "3": 56, "4": 188, "5": 458}                 37.0
# ..                                                 ...                  ...
# 495           {"1": 0, "2": 0, "3": 0, "4": 0, "5": 1}                  0.0
# 496  {"1": 527, "2": 638, "3": 1776, "4": 1703, "5"...                527.0
# 497     {"1": 44, "2": 23, "3": 67, "4": 61, "5": 146}                 44.0
# 498       {"1": 17, "2": 6, "3": 20, "4": 20, "5": 44}                 17.0
# 499     {"1": 48, "2": 18, "3": 50, "4": 59, "5": 375}                 48.0
#
#      reviews_per_score_2  reviews_per_score_3  reviews_per_score_4  \
# 0                    NaN                  NaN                  NaN
# 1                    7.0                 12.0                 41.0
# 2                   17.0                 44.0                189.0
# 3                   25.0                 49.0                154.0
# 4                   15.0                 56.0                188.0
# ..                   ...                  ...                  ...
# 495                  0.0                  0.0                  0.0
# 496                638.0               1776.0               1703.0
# 497                 23.0                 67.0                 61.0
# 498                  6.0                 20.0                 20.0
# 499                 18.0                 50.0                 59.0
#
#      reviews_per_score_5  photos_count  \
# 0                    NaN           1.0
# 1                   76.0         469.0
# 2                  484.0         212.0
# 3                  452.0         220.0
# 4                  458.0         255.0
# ..                   ...           ...
# 495                  1.0           8.0
# 496               2552.0        1730.0
# 497                146.0         229.0
# 498                 44.0         203.0
# 499                375.0         301.0
#
#                                                  photo  \
# 0    https://streetviewpixels-pa.googleapis.com/v1/...
# 1    https://lh5.googleusercontent.com/p/AF1QipPhWb...
# 2    https://lh5.googleusercontent.com/p/AF1QipOFu-...
# 3    https://lh5.googleusercontent.com/p/AF1QipPgjW...
# 4    https://lh5.googleusercontent.com/p/AF1QipODHj...
# ..                                                 ...
# 495  https://lh5.googleusercontent.com/p/AF1QipN2Hp...
# 496  https://lh5.googleusercontent.com/p/AF1QipP7MW...
# 497  https://lh5.googleusercontent.com/p/AF1QipP5u9...
# 498  https://lh3.googleusercontent.com/gps-proxy/AG...
# 499  https://lh5.googleusercontent.com/p/AF1QipOEqE...
#
#                                            street_view located_in  \
# 0    https://streetviewpixels-pa.googleapis.com/v1/...        NaN
# 1    https://lh5.googleusercontent.com/p/AF1QipPhWb...        NaN
# 2    https://lh5.googleusercontent.com/p/AF1QipOFu-...        NaN
# 3    https://lh5.googleusercontent.com/p/AF1QipPgjW...        NaN
# 4    https://lh5.googleusercontent.com/p/AF1QipODHj...        NaN
# ..                                                 ...        ...
# 495  https://lh5.googleusercontent.com/p/AF1QipN2Hp...        NaN
# 496  https://lh5.googleusercontent.com/p/AF1QipP7MW...        NaN
# 497  https://lh5.googleusercontent.com/p/AF1QipP5u9...        NaN
# 498  https://lh3.googleusercontent.com/gps-proxy/AG...        NaN
# 499  https://lh5.googleusercontent.com/p/AF1QipOEqE...        NaN
#
#                                          working_hours  \
# 0    {"Monday": "12-10pm", "Tuesday": "12-10pm", "W...
# 1    {"Monday": "Closed", "Tuesday": "1-8pm", "Wedn...
# 2    {"Monday": "Closed", "Tuesday": "9:30am-10pm",...
# 3    {"Monday": "11:30am-10pm", "Tuesday": "11:30am...
# 4    {"Monday": "12-11pm", "Tuesday": "12-11pm", "W...
# ..                                                 ...
# 495                                                NaN
# 496  {"Monday": "10AM-10PM", "Tuesday": "10AM-10PM"...
# 497                                                NaN
# 498                                                NaN
# 499                                                NaN
#
#                               working_hours_old_format other_hours  \
# 0    Monday: 12-10pm | Tuesday: 12-10pm | Wednesday...         NaN
# 1    Monday: Closed | Tuesday: 1-8pm | Wednesday: 1...         NaN
# 2    Monday: Closed | Tuesday: 9:30am-10pm | Wednes...         NaN
# 3    Monday: 11:30am-10pm | Tuesday: 11:30am-10pm |...         NaN
# 4    Monday: 12-11pm | Tuesday: 12-11pm | Wednesday...         NaN
# ..                                                 ...         ...
# 495                                                NaN         NaN
# 496  Monday: 10AM-10PM | Tuesday: 10AM-10PM | Wedne...         NaN
# 497                                                NaN         NaN
# 498                                                NaN         NaN
# 499                                                NaN         NaN
#
#      popular_times     business_status  \
# 0              NaN  CLOSED_TEMPORARILY
# 1              NaN         OPERATIONAL
# 2              NaN         OPERATIONAL
# 3              NaN         OPERATIONAL
# 4              NaN         OPERATIONAL
# ..             ...                 ...
# 495            NaN         OPERATIONAL
# 496            NaN         OPERATIONAL
# 497            NaN         OPERATIONAL
# 498            NaN         OPERATIONAL
# 499            NaN         OPERATIONAL
#
#                                                  about range  posts  \
# 0               {"Service options": {"Dine-in": true}}   NaN    NaN
# 1    {"Service options": {"Outdoor seating": true, ...     €    NaN
# 2    {"Service options": {"Outdoor seating": true, ...    €€    NaN
# 3    {"Service options": {"Outdoor seating": true, ...    €€    NaN
# 4    {"Service options": {"Outdoor seating": true, ...    €€    NaN
# ..                                                 ...   ...    ...
# 495                                                 {}   NaN    NaN
# 496                                                 {}   NaN    NaN
# 497                                                 {}   NaN    NaN
# 498                                                 {}   NaN    NaN
# 499                                                 {}   NaN    NaN
#
#                                                   logo  \
# 0                                                  NaN
# 1                                                  NaN
# 2    https://lh5.googleusercontent.com/-oSEqJTVfAIY...
# 3    https://lh5.googleusercontent.com/-yISH_CuJTwE...
# 4    https://lh4.googleusercontent.com/-bW8T2UVZQoA...
# ..                                                 ...
# 495                                                NaN
# 496                                                NaN
# 497  https://lh5.googleusercontent.com/-fAGX8ICCfeE...
# 498                                                NaN
# 499  https://lh4.googleusercontent.com/-mP40NsKjVZc...
#
#                                            description  verified  \
# 0                                                  NaN       0.0
# 1                                                  NaN       0.0
# 2    Relaxed eatery for hearty German cuisine such ...       1.0
# 3                                                  NaN       1.0
# 4                                                  NaN       1.0
# ..                                                 ...       ...
# 495                                                NaN       0.0
# 496  Down-to-earth shopping center featuring local ...       0.0
# 497  Relaxed hotel featuring breakfast & Wi-Fi, plu...       1.0
# 498                                                NaN       0.0
# 499  Modern rooms with flat-screens in a straightfo...       1.0
#
#                   owner_id                   owner_title  \
# 0                      NaN                  DE Americano
# 1                      NaN      Casino am Zwickauer Damm
# 2    110658667894733562714                Zum Alten Krug
# 3    103136462398260999967  Villa Toscana - Rudow Berlin
# 4    101120399137457846929                   Nea Politia
# ..                     ...                           ...
# 495                    NaN                       SÜTWEST
# 496                    NaN  Ömür Plaza Alışveriş Merkezi
# 497  108203759423799525189                   Otel Atabay
# 498                    NaN               Kocasinan Hotel
# 499  103184142399883873404            Green Garden Hotel
#
#                                             owner_link  \
# 0                                                  NaN
# 1                                                  NaN
# 2    https://www.google.com/maps/contrib/1106586678...
# 3    https://www.google.com/maps/contrib/1031364623...
# 4    https://www.google.com/maps/contrib/1011203991...
# ..                                                 ...
# 495                                                NaN
# 496                                                NaN
# 497  https://www.google.com/maps/contrib/1082037594...
# 498                                                NaN
# 499  https://www.google.com/maps/contrib/1031841423...
#
#                                      reservation_links  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    https://villatoscanaberlin.de/12767?modal=tabl...
# 4                          https://www.nea-politia.de/
# ..                                                 ...
# 495                                                NaN
# 496                                                NaN
# 497                                                NaN
# 498                                                NaN
# 499                                                NaN
#
#                               booking_appointment_link  menu_link  \
# 0                                                  NaN        NaN
# 1                                                  NaN        NaN
# 2                                                  NaN        NaN
# 3    https://villatoscanaberlin.de/12767?modal=tabl...        NaN
# 4                          https://www.nea-politia.de/        NaN
# ..                                                 ...        ...
# 495                                                NaN        NaN
# 496                                                NaN        NaN
# 497                                                NaN        NaN
# 498                                                NaN        NaN
# 499                                                NaN        NaN
#
#                                            order_links  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    https://villatoscanaberlin.de/12767?utm_source...
# 4                                                  NaN
# ..                                                 ...
# 495                                                NaN
# 496                                                NaN
# 497                                                NaN
# 498                                                NaN
# 499                                                NaN
#
#                                          location_link  \
# 0    https://www.google.com/maps/place/DE+Americano...
# 1    https://www.google.com/maps/place/Casino+am+Zw...
# 2    https://www.google.com/maps/place/Zum+Alten+Kr...
# 3    https://www.google.com/maps/place/Villa+Toscan...
# 4    https://www.google.com/maps/place/Nea+Politia/...
# ..                                                 ...
# 495  https://www.google.com/maps/place/S%C3%9CTWEST...
# 496  https://www.google.com/maps/place/%C3%96m%C3%B...
# 497  https://www.google.com/maps/place/Otel+Atabay/...
# 498  https://www.google.com/maps/place/Kocasinan+Ho...
# 499  https://www.google.com/maps/place/Green+Garden...
#
#                         place_id                              google_id  \
# 0    ChIJAXLdkGxGqEcR_ssCahqdDEE  0x47a8466c90dd7201:0x410c9d1a6a02cbfe
# 1    ChIJyZdeUddFqEcR18atclF8taw  0x47a845d7515e97c9:0xacb57c5172adc6d7
# 2    ChIJ25WZEG5GqEcRn8flzLGTYhs  0x47a8466e109995db:0x1b6293b1cce5c79f
# 3    ChIJ787AUWxGqEcRmEQVUW0v3jM  0x47a8466c51c0ceef:0x33de2f6d51154498
# 4    ChIJA_rFtl9GqEcR48IjW-qQWWI  0x47a8465fb6c5fa03:0x625990ea5b23c2e3
# ..                           ...                                    ...
# 495  ChIJwZyoCrW7yhQRezupTozWr7Q  0x14cabbb50aa89cc1:0xb4afd68c4ea93b7b
# 496  ChIJF7_2t0W7yhQRo_dNLpJAMfQ  0x14cabb45b7f6bf17:0xf43140922e4df7a3
# 497  ChIJSSKIHEi7yhQRX8TUNgLuEOI  0x14cabb481c882249:0xe210ee0236d4c45f
# 498  ChIJU-hCFVijyhQRJIlWKxHl46c  0x14caa3581542e853:0xa7e3e5112b568924
# 499  ChIJmwDZSPqjyhQRWDzHOevoWIo  0x14caa3fa48d9009b:0x8a58e8eb39c73c58
#
#                       cid             reviews_id located_google_id
# 0     4687294048959122430                                      NaN
# 1    12444989834566420183   -6001754239143131433               NaN
# 2     1973301978597803935    1973301978597803935               NaN
# 3     3737476887322379416    3737476887322379416               NaN
# 4     7086854824870003427    7086854824870003427               NaN
# ..                    ...                    ...               ...
# 495  13019860945854872443 -5426883127854679040.0               NaN
# 496  17595916215699503011  -850827858010048640.0               NaN
# 497  16289781545476342879 -2156962528233208832.0               NaN
# 498  12097764885951580452 -6348979187757971456.0               NaN
# 499   9968973872168909912 -8477770201540641792.0               NaN
#
# [5000 rows x 59 columns]

# %%
# double check shape, checks out
df.shape
# Out:
# (5000, 59)

# %%
# double check what happens with dus rows on that missing column 'area_service' - it is added and filled with NaNs
df[df['city']=='Düsseldorf'].head(3)
# Out:
#                                         query  \
# 0  restaurant, 40210, Nordrhein-Westfalen, DE
# 1  restaurant, 40210, Nordrhein-Westfalen, DE
# 2  restaurant, 40210, Nordrhein-Westfalen, DE
#
#                                                 name  \
# 0                          Restaurant Zum Schiffchen
# 1                                     Zum Kochlöffel
# 2  BLOCK HOUSE Düsseldorf Hauptbahnhof Harkortstraße
#
#                                       site        type  \
# 0  https://www.brauerei-zum-schiffchen.de/  Restaurant
# 1                                      NaN  Restaurant
# 2              https://www.block-house.de/  Restaurant
#
#                          subtypes     category             phone  \
# 0                      Restaurant  restaurants   +49 211 1701215
# 1                      Restaurant  restaurants   +49 211 1609615
# 2  Restaurant, Takeout restaurant  restaurants  +49 211 30137909
#
#                                   full_address        borough  \
# 0   Konrad-Adenauer-Platz 14, 40210 Düsseldorf  Stadtbezirk 1
# 1  Friedrich-Ebert-Straße 41, 40210 Düsseldorf  Stadtbezirk 1
# 2            Harkortstraße 8, 40210 Düsseldorf  Stadtbezirk 1
#
#                       street        city postal_code state  us_state  country  \
# 0   Konrad-Adenauer-Platz 14  Düsseldorf       40210   NaN       NaN  Germany
# 1  Friedrich-Ebert-Straße 41  Düsseldorf       40210   NaN       NaN  Germany
# 2            Harkortstraße 8  Düsseldorf       40210   NaN       NaN  Germany
#
#   country_code   latitude  longitude      time_zone  plus_code area_service  \
# 0           DE  51.220276   6.792887  Europe/Berlin        NaN          NaN
# 1           DE  51.221250   6.789820  Europe/Berlin        NaN          NaN
# 2           DE  51.219459   6.792052  Europe/Berlin        NaN          NaN
#
#    rating  reviews                                       reviews_link  \
# 0     3.5    251.0  https://search.google.com/local/reviews?placei...
# 1     4.5    116.0  https://search.google.com/local/reviews?placei...
# 2     4.5    135.0  https://search.google.com/local/reviews?placei...
#
#    reviews_tags                              reviews_per_score  \
# 0           NaN  {"1": 39, "2": 17, "3": 43, "4": 73, "5": 79}
# 1           NaN     {"1": 0, "2": 2, "3": 9, "4": 29, "5": 76}
# 2           NaN     {"1": 8, "2": 3, "3": 5, "4": 22, "5": 97}
#
#    reviews_per_score_1  reviews_per_score_2  reviews_per_score_3  \
# 0                 39.0                 17.0                 43.0
# 1                  0.0                  2.0                  9.0
# 2                  8.0                  3.0                  5.0
#
#    reviews_per_score_4  reviews_per_score_5  photos_count  \
# 0                 73.0                 79.0         117.0
# 1                 29.0                 76.0          18.0
# 2                 22.0                 97.0         284.0
#
#                                                photo  \
# 0  https://lh5.googleusercontent.com/p/AF1QipMU8-...
# 1  https://lh5.googleusercontent.com/p/AF1QipNyyl...
# 2  https://lh5.googleusercontent.com/p/AF1QipO0So...
#
#                                          street_view located_in  \
# 0  https://lh5.googleusercontent.com/p/AF1QipMU8-...        NaN
# 1  https://lh5.googleusercontent.com/p/AF1QipNyyl...        NaN
# 2  https://lh5.googleusercontent.com/p/AF1QipO0So...        NaN
#
#                                        working_hours  \
# 0  {"Monday": "8am-11pm", "Tuesday": "8am-11pm", ...
# 1  {"Monday": "6am-5pm", "Tuesday": "6am-5pm", "W...
# 2  {"Monday": "12-10pm", "Tuesday": "12-10pm", "W...
#
#                             working_hours_old_format other_hours  \
# 0  Monday: 8am-11pm | Tuesday: 8am-11pm | Wednesd...         NaN
# 1  Monday: 6am-5pm | Tuesday: 6am-5pm | Wednesday...         NaN
# 2  Monday: 12-10pm | Tuesday: 12-10pm | Wednesday...         NaN
#
#    popular_times business_status  \
# 0            NaN     OPERATIONAL
# 1            NaN     OPERATIONAL
# 2            NaN     OPERATIONAL
#
#                                                about range  posts  \
# 0  {"Service options": {"Takeaway": true, "Dine-i...    €€    NaN
# 1  {"Service options": {"Takeaway": true, "Dine-i...     €    NaN
# 2  {"Service options": {"Outdoor seating": true, ...    €€    NaN
#
#                                                 logo description  verified  \
# 0  https://lh3.googleusercontent.com/-57mb-s1US0w...         NaN       1.0
# 1                                                NaN         NaN       0.0
# 2  https://lh6.googleusercontent.com/-dky986dbAPo...         NaN       1.0
#
#                 owner_id                                        owner_title  \
# 0  117181584539908212891                          Restaurant Zum Schiffchen
# 1                    NaN                                     Zum Kochlöffel
# 2  111611767742001152293  BLOCK HOUSE Düsseldorf Hauptbahnhof Harkortstraße
#
#                                           owner_link reservation_links  \
# 0  https://www.google.com/maps/contrib/1171815845...               NaN
# 1                                                NaN               NaN
# 2  https://www.google.com/maps/contrib/1116117677...               NaN
#
#   booking_appointment_link  menu_link order_links  \
# 0                      NaN        NaN         NaN
# 1                      NaN        NaN         NaN
# 2                      NaN        NaN         NaN
#
#                                        location_link  \
# 0  https://www.google.com/maps/place/Restaurant+Z...
# 1  https://www.google.com/maps/place/Zum+Kochl%C3...
# 2  https://www.google.com/maps/place/BLOCK+HOUSE+...
#
#                       place_id                              google_id  \
# 0  ChIJdfp4DzHKuEcRZfa1cQU-eT8  0x47b8ca310f78fa75:0x3f793e0571b5f665
# 1  ChIJ7zsnfTDKuEcRfy0611XzbqE  0x47b8ca307d273bef:0xa16ef355d73a2d7f
# 2  ChIJm5X1eEfLuEcRseySaZn3Aps  0x47b8cb4778f5959b:0x9b02f7996992ecb1
#
#                     cid             reviews_id located_google_id
# 0   4573755089674958437  4573755089674958336.0               NaN
# 1  11632502437553253759 -6814241636156297216.0               NaN
# 2  11169762264105544881 -7276981809604005888.0               NaN

# %%
# # obtain column headers to print a markdown table
# header = []
# for col in df.columns:
    #print(col)
    #print('|',col,'||')
#     header.append(col)
# header

# %% [markdown]
# We have 59 columns in total, but most don't make sense for our further data processing. Time to drop:
#
# | Column Name | Drop or Keep and why |
# | :---------- | :------------------- |
# | query | drop, refers to the query from outscraper to GMaps |
# | name | keep |
# | site | keep (for now), website link of restaurant if any (otherwise NaN) |
# | type | keep (for now), defines locale as restaurant (or other) |
# | subtypes | keep (for now) |
# | category | keep (for now) |
# | phone | keep (for now) |
# | full_address | keep (for now), technically a duplicate |
# | borough | keep (for now), may be useless or could play a factor in weighing a restaurant by location |
# | street | keep (for now), technically a duplicate |
# | city | keep (for now), technically a duplicate |
# | postal_code | keep (for now), technically a duplicate |
# | state | drop |
# | us_state | drop |
# | country | keep (for now) |
# | country_code | drop, duplicate |
# | latitude | keep (for now), may be needed when plotting location on a map |
# | longitude | keep (for now), may be needed when plotting location on a map |
# | time_zone | drop |
# | plus_code | drop, use case unknown |
# | area_service | drop, use case unknown |
# | rating | keep, aggregate review score |
# | reviews | keep, number of reviews |
# | reviews_link | drop |
# | reviews_tags | drop, use case unknown |
# | reviews_per_score | drop, duplicate |
# | reviews_per_score_1 | keep (for now), could be useful |
# | reviews_per_score_2 | keep (for now), could be useful |
# | reviews_per_score_2 | keep (for now), could be useful |
# | reviews_per_score_3 | keep (for now), could be useful |
# | reviews_per_score_4 | keep (for now), could be useful |
# | reviews_per_score_5 | keep (for now), could be useful |
# | photos_count | keep (for now), could be useful |
# | photo | drop |
# | street_view | drop |
# | located_in | drop |
# | working_hours | drop |
# | working_hours_old_format | drop |
# | other_hours | drop |
# | popular_times | drop |
# | business_status | drop |
# | about | keep (for now), could be useful |
# | range | keep |
# | posts | drop |
# | logo | drop |
# | description | drop |
# | verified | drop |
# | owner_id | drop |
# | owner_title | drop |
# | owner_link | drop |
# | reservation_links | drop |
# | booking_appointment_link | drop |
# | menu_link | drop |
# | order_links | drop |
# | location_link | drop |
# | place_id | drop |
# | google_id | drop |
# | cid | drop |
# | reviews_id | drop |
# | located_google_id | drop |

# %%
# Will drop some irrelevant columns prior to exporting to .csv and MySQL

df=df.drop(['query','state','us_state','country_code','time_zone','plus_code','area_service','reviews_link','reviews_tags','reviews_per_score','photo','street_view','located_in','working_hours','working_hours_old_format','other_hours','popular_times','business_status','posts','logo','description','verified','owner_id','owner_title','owner_link','reservation_links','booking_appointment_link','menu_link','order_links','location_link','place_id','google_id','cid','reviews_id','located_google_id'],axis=1)
df.head(1)
# Out:
#            name site        type    subtypes     category phone  \
# 0  DE Americano  NaN  Restaurant  Restaurant  restaurants   NaN
#
#                         full_address   borough               street    city  \
# 0  Köpenicker Str. 130, 12355 Berlin  Neukölln  Köpenicker Str. 130  Berlin
#
#   postal_code  country  latitude  longitude  rating  reviews  \
# 0     12355.0  Germany  52.42134  13.503272     NaN      NaN
#
#    reviews_per_score_1  reviews_per_score_2  reviews_per_score_3  \
# 0                  NaN                  NaN                  NaN
#
#    reviews_per_score_4  reviews_per_score_5  photos_count  \
# 0                  NaN                  NaN           1.0
#
#                                     about range
# 0  {"Service options": {"Dine-in": true}}   NaN

# %% [markdown]
# #### My column headers are already in the proper format, no need to edit those. The df as is seems to have a lot of NaN values and irrelevant columns that I could just drop. Before cleaning my data however, I wanted to export my concatenated df and import it to SQL
#
# **NOTE:** below cells are commented out so as to not run them repeatedly if I were to restart the kernel and run all cells again. They confirm to work and have been previously executed.

# %%
# # exporting df to .csv for safekeeping and to migrate over to SQL
# df.to_csv('All_Cities.csv', index=False)

# %%
# df.to_sql('all_cities', engine, index=False)
# Out:
# 5000
